# %% [markdown]
# **Review**
#
# Hi, my name is Dmitry and I will be reviewing your project.
#
# You can find my comments in colored markdown cells:
#
# <div class="alert alert-success">
#   If everything is done successfully.
# </div>
#
# <div class="alert alert-warning">
#   If I have some (optional) suggestions, or questions to think about, or general comments.
# </div>
#
# <div class="alert alert-danger">
#   If a section requires some corrections. Work can't be accepted with red comments.
# </div>
#
# Please don't remove my comments, as it will make further review iterations much harder for me.
#
# Feel free to reply to my comments or ask questions using the following template:
#
# <div class="alert alert-info">
#   For your comments and questions.
# </div>
#
# First of all, thank you for turning in the project! You did a pretty good job overall, but one unfortunate mistake made the bootstrap profit results incorrect. See comments below for details. Let me know if you have any questions!

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment</b> <br>
# <br>
# Thanks for your help.<br>
# This project was very interesting and I learned a lot.<br>
# It was also very frustrating.<br>
# I started writing unit tests, and wrote and rewrote the bootstrapping functions several times.<br>
# Finally I went back and tested the changes, and started getting viable outputs.<br>
# I think I failed to fix a random seed somewhere, consequently the numbers bounce around a bit from run to run.<br>
# - update - fixed the random_state = 42 <br>
# Updated some of the end of chapter reports to be auto generated and always up to date.<br>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment V2</b>
#
# Dear Adam, thanks for all your hard work, but it seems that my earlier comments were not quite clear, and I'm really sorry if that's the case. I tried to make some clarifications and expand below. Please send back the project and let me know if something is unclear before wasting any more time :)
#
# </div>

# %% [markdown]
# # Sprint 9. Machine Learning in Business
# ## Project description
# You work for the OilyGiant mining company. Your task is to find the best place for a new well.
# Steps to choose the location:
# * Collect the oil well parameters in the selected region: oil quality and volume of reserves;
# * Build a model for predicting the volume of reserves in the new wells;
# * Pick the oil wells with the highest estimated values;
# * Pick the region with the highest total profit for the selected oil wells.
# You have data on oil samples from three regions. Parameters of each oil well in the region are already known. Build a model that will help to pick the region with the highest profit margin. Analyze potential profit and risks using the Bootstrapping technique.
# ## Data description
# Geological exploration data for the three regions are stored in files:
# * geo_data_0.csv. download dataset
# * geo_data_1.csv. download dataset
# * geo_data_2.csv. download dataset
# * id — unique oil well identifier
# * f0, f1, f2 — three features of points (their specific meaning is unimportant, but the features themselves are significant)
# * product — volume of reserves in the oil well (thousand barrels).
# ## Conditions:
# * Only linear regression is suitable for model training (the rest are not sufficiently predictable).
# * When exploring the region, a study of 500 points is carried with picking the best 200 points for the profit calculation.
# * The budget for development of 200 oil wells is 100 USD million.
# * One barrel of raw materials brings 4.5 USD of revenue The revenue from one unit of product is 4,500 dollars (volume of reserves is in thousand barrels).
# * After the risk evaluation, keep only the regions with the risk of losses lower than 2.5%. From the ones that fit the criteria, the region with the highest average profit should be selected.

# %% [markdown]
# # 1. Download and prepare the data.
# Explain the procedure.

# %%
# Load libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kde

# %%
import numpy as np
import random

# Fix the random seeds
random_seed = 42
np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## 1.2  Load the Data
# This function downloads the datasets, saves them in a local 'datasets' folder, and loads them into pandas DataFrames.

# %%
import os
import pandas as pd

def download_and_load_datasets():
    # Check if the datasets folder exists
    if not os.path.exists('datasets'):
        os.makedirs('datasets')

    # Download the source CSV files and save them in the datasets folder
    urls = [
        'https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_0.csv',
        'https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_1.csv',
        'https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_2.csv'
    ]
    filenames = ['geo_data_0.csv', 'geo_data_1.csv', 'geo_data_2.csv']
    
    data = []

    for url, filename in zip(urls, filenames):
        try:
            df = pd.read_csv(url)
        except:
            df = pd.read_csv(url)
        
        df.to_csv(f'datasets/{filename}')
        data.append(df)
    
    return data

data = download_and_load_datasets()

# %% [markdown]
# # 2. Train and test the model for each region

# %% [markdown]
# This code saves the average predicted volumes and RMSE values for each region in separate lists, so you can easily use them later in the analysis without hardcoding the values. <br>
# 2.3 It also creates a dictionary called region_result for each region and stores the predictions and correct answers in it. These dictionaries are then appended to the region_results list, which will contain the results for all regions.

# %%
from sklearn.metrics import r2_score

region_averages = []
region_rmse = []
targets_valid = []
predictions_list = []

# for i, region in enumerate(data):
#     # 2.1. Split the data into a training set and validation set at a ratio of 75:25
#     features = region.drop(['id', 'product'], axis=1)
#     target = region['product']
#     features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.25, random_state=42)

#     # # 2.2. Train the model and make predictions for the validation set
#     model = LinearRegression()
#     model.fit(features_train, target_train)
#     predictions = model.predict(features_valid)

#     # 2.3. Save the predictions and correct answers for the validation set
#     targets_valid.append(target_valid)
#     predictions_list.append(pd.Series(predictions, index=target_valid.index))

#     # 2.4. Calculate the average volume of predicted reserves and model RMSE
#     rmse = mean_squared_error(target_valid, predictions, squared=False)
#     avg_predicted_volume = predictions.mean()

#     # Save region averages and RMSE to their respective lists
#     region_averages.append(avg_predicted_volume)
#     region_rmse.append(rmse)

for i, region in enumerate(data):
    # 2.1. Split the data into a training set and validation set at a ratio of 75:25
    features = region.drop(['id', 'product'], axis=1)
    target = region['product']
    features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.25, random_state=42)

    # 2.2. Train the model and make predictions for the validation set
    model = LinearRegression()
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)

    # Calculate R-squared score
    r2_score_value = r2_score(target_valid, predictions)

    # 2.3. Save the predictions and correct answers for the validation set
    targets_valid.append(target_valid)
    predictions_list.append(pd.Series(predictions, index=target_valid.index))

    # 2.4. Calculate the average volume of predicted reserves and model RMSE
    rmse = mean_squared_error(target_valid, predictions, squared=False)
    avg_predicted_volume = predictions.mean()

    # Save region averages and RMSE to their respective lists
    region_averages.append(avg_predicted_volume)
    region_rmse.append(rmse)

    print(f"Region {i}: Average predicted volume: {avg_predicted_volume}, RMSE: {rmse}, R-squared: {r2_score_value}")

    # Plot target and predictions distributions
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(target, kde=True)
    plt.title(f"Region {i}: Target Distribution")

    plt.subplot(1, 2, 2)
    sns.histplot(predictions, kde=True)
    plt.title(f"Region {i}: Predictions Distribution")

    plt.show()

    # print(f"Region {i}: Average predicted volume: {avg_predicted_volume}, RMSE: {rmse}")
# Out:
# Region 0: Average predicted volume: 92.39879990657768, RMSE: 37.75660035026169, R-squared: 0.2728287328173471
# Region 1: Average predicted volume: 68.71287803913762, RMSE: 0.8902801001028858, R-squared: 0.9996245232002449
# Region 2: Average predicted volume: 94.77102387765939, RMSE: 40.14587231134218, R-squared: 0.19634705977280464

# %% [markdown]
# ### The R-squared values for each region indicate the following:
#
# Region 0: The R-squared value of 0.27 suggests that the linear regression model is only able to explain 27% of the variance in the target variable. This means that the model is not performing well on this region's data.
#
# Region 1: The R-squared value of 0.9996 suggests that the linear regression model can explain 99.96% of the variance in the target variable. This is an extremely high value, indicating that the model performs well on the data from this region. However, it's worth noting that such a high R-squared value could be a sign of overfitting, which means that the model may not generalize well to unseen data.
#
# Region 2: The R-squared value of 0.196 indicates that the linear regression model is only able to explain 19.6% of the variance in the target variable. Similar to Region 0, the model is not performing well on this region's data.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Good, the data for each region was split into train and validation sets, the models were trained and evaluated correctly
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment</b>
#
# updated r2 and added graph while trouble shooting another section.
#
# </div>

# %% [markdown]
# ## 2.5 Analyze the results
# ### Discuss the model performance for each region
# | Region | Average Predicted Volume (thousand barrels) | RMSE   |
# |--------|---------------------------------------------|--------|
# | 0      | 92.5925                                    | 37.5794|
# | 1      | 68.7285                                    | 0.8931 |
# | 2      | 94.9650                                    | 40.0297|
#
#
# From these results, we can observe that the average predicted volumes of oil reserves for Region 0 and Region 2 are higher than that of Region 1. However, the RMSE is also significantly higher for both Region 0 and Region 2, indicating that the model's predictions have a larger margin of error in these regions.
#
# On the other hand, the RMSE for Region 1 is very low, which implies that the model's predictions are more accurate for this region. This could be beneficial when making decisions about which wells to develop, as there is a higher level of certainty in the predicted oil reserves.
#
# In the next sections, we will calculate the potential profit and risk for each region, which will help us to make a better-informed decision about which region to select for oil well development.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Conclusions make sense
#
# </div>

# %% [markdown]
# # 3. Prepare for profit calculation

# %% [markdown]
# ## 3.1. Store all key values for calculations in separate variables

# %%
# 3.1. Store all key values for calculations in separate variables
BUDGET = 100_000_000
REVENUE_PER_THOUSAND_BARRELS = 4_500
WELLS_FOR_DEVELOPMENT = 200

# %% [markdown]
# ## 3.2. Calculate the volume of reserves sufficient for developing a new well without losses.
# Compare the obtained value with the average volume of reserves in each region.
# This code will print the break-even volume and the average predicted volume for each region, and indicate whether the average predicted volume is above or below the break-even volume.

# %%
break_even_volume = BUDGET / (WELLS_FOR_DEVELOPMENT * REVENUE_PER_THOUSAND_BARRELS)
print("Break-even volume (thousand barrels):", break_even_volume)
# Out:
# Break-even volume (thousand barrels): 111.11111111111111

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Calculation is correct
#
# </div>

# %% [markdown]
# ## 3.3. Provide the findings about the preparation for profit calculation step

# %%
# 3.3. Provide the findings about the preparation for profit calculation step
# Summarize the findings
print("Break-even volume (thousand barrels):", break_even_volume)

for i, avg in enumerate(region_averages):
    print(f"Region {i}:")
    print(f"  Average predicted volume (thousand barrels): {avg}")
    difference = avg - break_even_volume
    if difference >= 0:
        print(f"  The average predicted volume in Region {i} is {abs(difference):.2f} thousand barrels above the break-even volume.")
    else:
        print(f"  The average predicted volume in Region {i} is {abs(difference):.2f} thousand barrels below the break-even volume.")
# Out:
# Break-even volume (thousand barrels): 111.11111111111111
# Region 0:
#   Average predicted volume (thousand barrels): 92.39879990657768
#   The average predicted volume in Region 0 is 18.71 thousand barrels below the break-even volume.
# Region 1:
#   Average predicted volume (thousand barrels): 68.71287803913762
#   The average predicted volume in Region 1 is 42.40 thousand barrels below the break-even volume.
# Region 2:
#   Average predicted volume (thousand barrels): 94.77102387765939
#   The average predicted volume in Region 2 is 16.34 thousand barrels below the break-even volume.

# %%
import matplotlib.pyplot as plt

regions = ['Region 0', 'Region 1', 'Region 2']
plt.bar(regions, region_averages, label='Average Predicted Volume')
plt.axhline(y=break_even_volume, color='r', linestyle='--', label='Break-even Volume')

plt.xlabel('Regions')
plt.ylabel('Volume (thousand barrels)')
plt.title('Average Predicted Volume vs. Break-even Volume')
plt.legend()
plt.show()

# %% [markdown]
# So far, we have performed the following tasks:
#
# 1. **Downloaded and prepared the data** for three regions.
# 2. **Trained and tested a linear regression model** for each region. We calculated the average predicted volume of reserves and the RMSE for each region. Here are the results:
#
#    - Region 0: Average predicted volume: 92.59 thousand barrels, RMSE: 37.58
#    - Region 1: Average predicted volume: 68.73 thousand barrels, RMSE: 0.89
#    - Region 2: Average predicted volume: 94.97 thousand barrels, RMSE: 40.03
#
# 3. **Calculated the break-even volume** of reserves needed for developing a new well without losses, which is 111.11 thousand barrels.
#
# We compared the average predicted volume of reserves for each region with the break-even volume:
#
#    - Region 0 has an average predicted volume of 92.59 thousand barrels, which is 18.52 thousand barrels below the break-even volume.
#    - Region 1 has an average predicted volume of 68.73 thousand barrels, which is 42.38 thousand barrels below the break-even volume.
#    - Region 2 has an average predicted volume of 94.97 thousand barrels, which is 16.14 thousand barrels below the break-even volume.
#
# Based on these findings, none of the regions has an average predicted volume of reserves above the break-even volume. However, **Region 2 is the closest to the break-even point**, followed by Region 0. Region 1 has the lowest average predicted volume of reserves and the lowest RMSE, indicating that the model's predictions for this region are more precise but the potential reserves are lower.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Well done!
#
# </div>

# %% [markdown]
# # 4. Write a function to calculate profit from a set of selected oil wells and model predictions

# %% [markdown]
# ## 4.1. Pick the wells with the highest values of predictions

# %% [markdown]
# The calculate_profit function takes three input arguments: target, predictions, and count. The target variable contains the true reserves of the wells, while predictions holds the predicted reserves. The count parameter represents the number of wells to be developed.
#
# The function first resets and drops the indices of both target and predictions. This ensures that the indices match and can be used for selecting the corresponding elements between them.
#
# The predictions are sorted in descending order, and the top count wells with the highest predicted reserves are selected. The indices of these top wells are stored in the top_wells variable.
#
# Using the indices in top_wells, the corresponding true reserves in the target are selected and summed to obtain the total_reserves.
#
# The revenue is then calculated by multiplying the total_reserves by the REVENUE_PER_THOUSAND_BARRELS constant.
#
# The profit is calculated by subtracting the BUDGET constant from the revenue.
#
# The function finally returns the calculated profit.
#
# This function essentially calculates the profit for developing the top count wells, based on the given predictions and true reserves.

# %%
### V2

def calculate_profit(target, predictions, count):
    # Reset and drop indices of target and predictions
    target = target.reset_index(drop=True)
    predictions = predictions.reset_index(drop=True)

    top_wells = predictions.sort_values(ascending=False).head(count).index
    total_reserves = target.loc[top_wells].sum()
    revenue = total_reserves * REVENUE_PER_THOUSAND_BARRELS
    profit = revenue - BUDGET
    return profit

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment V2</b>
#
# Function for profit calculation is correct now!
#
# </div>

# %% [markdown]
# The calculate_profits_for_regions function takes three input arguments: targets, predictions_list, and count. The targets variable is a list containing the true reserves of the wells for multiple regions, while predictions_list is a list of predicted reserves for the same regions. The count parameter represents the number of wells to be developed in each region.
#
# The function initializes an empty dictionary called profits, which will be used to store the calculated profit for each region.
#
# The function iterates over the targets and predictions_list using the enumerate() function. This provides both the index (i) and the corresponding target and predictions values for each region.
#
# For each region, the function calls the calculate_profit function, passing in the target, predictions, and count arguments. The result is stored in the profit variable.
#
# The calculated profit for each region is then added to the profits dictionary, with the region index (i) as the key.
#
# After iterating through all the regions, the function returns the profits dictionary.
#
# This function calculates and stores the profit for each region, given the true reserves and predictions, by calling the calculate_profit function for each region.

# %%
### v2

def calculate_profits_for_regions(targets, predictions_list, count):
    profits = {}

    for i, (target, predictions) in enumerate(zip(targets, predictions_list)):
        profit = calculate_profit(target, predictions, count)
        profits[i] = profit

    return profits

# %% [markdown]
# This code block calculates the profits for each region using the calculate_profits_for_regions function. It takes in three arguments: targets_valid, predictions_list, and WELLS_FOR_DEVELOPMENT.
#
# targets_valid is a list of true reserves for the validation wells in each region, and predictions_list is a list of predicted reserves for the same validation wells. WELLS_FOR_DEVELOPMENT is the number of wells to be developed in each region.
#
# The calculate_profits_for_regions function is called with these arguments, and the resulting profits for each region are stored in the region_profits variable, which is a dictionary with the region index as the key and the profit value as the associated value.
#
# This code block computes the profits for each region, considering the true reserves, predictions, and the number of wells to be developed.

# %%
# Calculate the profits for each region
region_profits = calculate_profits_for_regions(targets_valid, predictions_list, WELLS_FOR_DEVELOPMENT)

# %% [markdown]
# This code block prints the profits for each region calculated in the previous step. It iterates through the region_profits dictionary, which contains the region index as the key and the corresponding profit as the value.
#
# For each item in the dictionary, the code block prints a formatted string displaying the region index and the profit in USD. This provides a clear and readable output of the profits for each region based on the true reserves, predictions, and the number of wells to be developed.

# %%
# Print the profits for each region
for i, profit in region_profits.items():
    print(f"Region {i}: Profit: {profit} USD")
# Out:
# Region 0: Profit: 33591411.14462179 USD
# Region 1: Profit: 24150866.966815114 USD
# Region 2: Profit: 25985717.59374112 USD

# %% [markdown]
# We create a test class called TestProfitCalculation that inherits from unittest.TestCase. We define two test methods: test_calculate_profit and test_calculate_profits_for_regions. In each test method, we define sample input data and expected output, then call the respective function with the sample input data and compare the actual output with the expected output using the appropriate unittest assertion methods (assertAlmostEqual for floating-point comparisons and assertEqual for dictionary comparisons).
#
# These tests are basic and serve as a starting point. You can add more test cases to cover different scenarios and edge cases to ensure that the functions work correctly in various situations.
#
# To run the tests, simply include the test class and call unittest.main(argv=[""], exit=False) at the end of the script. This will execute all test methods in the TestProfitCalculation class and display the test results.

# %%
import unittest

class TestProfitCalculation(unittest.TestCase):
    
    def test_calculate_profit(self):
        target = pd.Series([100, 50, 30, 20, 10])
        predictions = pd.Series([100, 50, 30, 20, 10], index=[0, 1, 2, 3, 4])
        count = 2

        actual_profit = calculate_profit(target, predictions, count)

        # Update the expected profit value
        expected_profit = (100 + 50) * REVENUE_PER_THOUSAND_BARRELS - BUDGET
        self.assertAlmostEqual(expected_profit, actual_profit, places=2)

    def test_calculate_profits_for_regions(self):
        targets = [pd.Series([100, 50, 30, 20, 10]), pd.Series([120, 60, 40, 30, 20])]
        predictions_list = [pd.Series([100, 50, 30, 20, 10], index=[0, 1, 2, 3, 4]),
                            pd.Series([120, 60, 40, 30, 20], index=[0, 1, 2, 3, 4])]
        count = 2

        actual_profits = calculate_profits_for_regions(targets, predictions_list, count)

        # Update the expected profits values
        expected_profits = {
            0: (100 + 50) * REVENUE_PER_THOUSAND_BARRELS - BUDGET,
            1: (120 + 60) * REVENUE_PER_THOUSAND_BARRELS - BUDGET,
        }
        self.assertEqual(expected_profits, actual_profits)


if __name__ == "__main__":
    unittest.main(argv=[""], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.005s
#
# OK

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment V2</b>
#
# Cool idea to add unit tests, though it was not required :)
#
# </div>

# %% [markdown]
# the bootstrap_resample_test function takes targets, predictions, count, and an optional n_iterations parameter. The function performs bootstrap resampling n_iterations times, and for each iteration, it checks if the number of unique indices in the top_wells Series is equal to count. If they are not equal, a message is printed, indicating that there are repeating indices in this iteration.
#
# You can call this function with your targets_valid and predictions_list for each region to check for repeating indices:

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Function to calculate profit
def calculate_profit(target, predictions, count):
    BUDGET = 100_000_000  # Total budget
    REVENUE_PER_UNIT = 4_500  # Revenue per product unit
    COST_PER_WELL = BUDGET / count  # Cost per well development

    top_wells = predictions.sort_values(ascending=False).head(count).index
    profit = (REVENUE_PER_UNIT * target.loc[top_wells].sum()) - (COST_PER_WELL * count)
    return profit

# %%
def bootstrap_resample(target, predictions, count, revenue_per_unit, cost_per_well, n_iterations=1000):
    n_samples = len(target)
    profits_list = []

    for i in range(n_iterations):
        # Sample 500 rows with replacement from predictions/targets
        resampled_indices = np.random.choice(target.index, size=n_samples, replace=True)
        resampled_target = target.loc[resampled_indices].reset_index(drop=True)
        resampled_predictions = predictions.loc[resampled_indices].reset_index(drop=True)

        # Give the sampled predictions and targets to the profit calculation function
        profit = calculate_profit(resampled_target, resampled_predictions, count)
        profits_list.append(profit)

    return profits_list

# %%
# Perform bootstrap resampling for each region
bootstrap_profits = []

for i, (target, predictions) in enumerate(zip(targets_valid, predictions_list)):
    cost_per_well = BUDGET / WELLS_FOR_DEVELOPMENT
    profits_list = bootstrap_resample(target, predictions, WELLS_FOR_DEVELOPMENT, REVENUE_PER_THOUSAND_BARRELS, cost_per_well)
    bootstrap_profits.append(profits_list)

# Calculate confidence intervals and risks for each region and store the statistics
statistics = []
for i, profits in enumerate(bootstrap_profits):
    mean_profit = np.mean(profits)
    lower_bound, upper_bound = np.percentile(profits, [2.5, 97.5])
    risk = (np.array(profits) < 0).mean() * 100
    statistics.append((mean_profit, lower_bound, upper_bound, risk))

    print(f"Region {i}:")
    print(f"  Mean profit: {mean_profit:.2f} USD")
    print(f" 95% confidence interval: ({lower_bound:.2f}, {upper_bound:.2f}) USD")
    print(f" Risk: {risk:.2f}%\n")
# Out:
# Region 0:
#   Mean profit: 33719318.41 USD
#  95% confidence interval: (30437973.79, 37376105.23) USD
#  Risk: 0.00%
#
# Region 1:
#   Mean profit: 24150866.97 USD
#  95% confidence interval: (24150866.97, 24150866.97) USD
#  Risk: 0.00%
#
# Region 2:
#   Mean profit: 25641761.10 USD
#  95% confidence interval: (21774873.07, 29199273.87) USD
#  Risk: 0.00%

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kde

def plot_profit_distribution(profits_list, region_index):
    try:
        sns.histplot(profits_list, bins=50, kde=True)
    except np.linalg.LinAlgError:
        sns.histplot(profits_list, bins=50, kde=False)
        print(f"Region {region_index}: KDE plot failed due to singular matrix error. Plotting histogram without KDE.")
    
    plt.xlabel("Profit (USD)")
    plt.ylabel("Frequency")
    plt.title(f"Profit Distribution for Region {region_index}")
    plt.show()

# Perform bootstrap resampling for each region, calculate statistics and plot profit distributions
bootstrap_profits = []
statistics = []

for i, (target, predictions) in enumerate(zip(targets_valid, predictions_list)):
    print(f"Checking Region {i}:")
    cost_per_well = BUDGET / WELLS_FOR_DEVELOPMENT
    profits_list = bootstrap_resample(target, predictions, WELLS_FOR_DEVELOPMENT, REVENUE_PER_THOUSAND_BARRELS, cost_per_well)
    bootstrap_profits.append(profits_list)

    mean_profit = np.mean(profits_list)
    lower_bound, upper_bound = np.percentile(profits_list, [2.5, 97.5])
    risk = (np.array(profits_list) < 0).mean() * 100
    statistics.append((mean_profit, lower_bound, upper_bound, risk))

    print(f"Region {i}:")
    print(f"  Mean profit: {mean_profit:.2f} USD")
    print(f" 95% confidence interval: ({lower_bound:.2f}, {upper_bound:.2f}) USD")
    print(f" Risk: {risk:.2f}%\n")

    plot_profit_distribution(profits_list, i)
    print()
# Out:
# Checking Region 0:
# Region 0:
#   Mean profit: 33575551.49 USD
#  95% confidence interval: (29954907.95, 37162932.11) USD
#  Risk: 0.00%
# Checking Region 1:
# Region 1:
#   Mean profit: 24150866.97 USD
#  95% confidence interval: (24150866.97, 24150866.97) USD
#  Risk: 0.00%
#
# Region 1: KDE plot failed due to singular matrix error. Plotting histogram without KDE.
# Checking Region 2:
# Region 2:
#   Mean profit: 25640084.80 USD
#  95% confidence interval: (21856570.99, 29101176.20) USD
#  Risk: 0.00%

# %% [markdown]
# V1 outputs: <br>
# Region 0: Profit: 33208260.43139851 USD <br>
# Region 1: Profit: 24150866.966815114 USD <br>
# Region 2: Profit: 27103499.635998324 USD <br>

# %%
# display(predictions)
# display(target)

# %% [markdown]
# ## 4.1 annalysis of the results thus far:
#
# In this analysis, we have examined the potential profits of developing oil wells in three regions. We used a bootstrap resampling technique to account for uncertainty in the predictions and calculated the average profit for each region. The results are as follows: <br>
# <br>
# * Region 0: Profit: 33,208,260.43 USD <br>
# * Region 1: Profit: 24,150,866.97 USD <br>
# * Region 2: Profit: 27,103,499.64 USD <br>
# To ensure the accuracy of our calculations, we created unit tests for the calculate_profit and calculate_profits_for_regions functions. Both tests passed successfully.  <br>
# <br>
# We then investigated the code reviewer's concern about the possibility of repeating indices in the targets/predictions after the bootstrap resampling process. We found that the count of unique top_wells can be less than the expected count due to the sampling with replacement process. This limitation should be considered when interpreting the results of the analysis. <br>
# <br>
# The output of the bootstrap resampling test showed the following discrepancy in the unique top_wells count for each region: <br>
# <br>
# * Checking Region 0: Iteration 0: Unique top_wells count (125) does not equal 200. <br>
# * Checking Region 1: Iteration 0: Unique top_wells count (133) does not equal 200. <br>
# * Checking Region 2: Iteration 0: Unique top_wells count (122) does not equal 200. <br>
# Overall, our analysis suggests that Region 0 has the highest potential profit among the three regions. However, it is important to consider the limitations of the bootstrap resampling process when interpreting these results. <br>

# %% [markdown]
# ### Trying to understand why we're still having this issue...
# by checking the lengths of targets_valid and predictions_list, we can find out how many points are being considered for each region. <br>
# <br>
# If the number of points is not 500 for each region as mentioned in the project description, we may need to adjust our data preprocessing steps to ensure that 500 points are considered for each region.

# %%
for i, (target, predictions) in enumerate(zip(targets_valid, predictions_list)):
    print(f"Region {i}: {len(target)} points")
# Out:
# Region 0: 25000 points
# Region 1: 25000 points
# Region 2: 25000 points

# %% [markdown]
# ### 25,000 points for each region
# hmm... The targets_valid and predictions_list contain data for all the wells in each region (25,000 points), but during the bootstrap resampling, only the top 200 wells are being considered for profit calculation. The reason why the "Unique top_wells count" is less than 200 is that some wells are being selected more than once during the resampling process.

# %%
# create a function that will randomly select 500 points from the given target and predictions

def select_random_points(target, predictions, n_points=500):
    random_indices = np.random.choice(target.index, size=n_points, replace=False)
    return target.loc[random_indices], predictions.loc[random_indices]

# %% [markdown]
# create two empty lists to store the randomly selected targets and predictions for each region:

# %%
random_targets_valid = []
random_predictions_list = []

# %% [markdown]
# loop through the original targets and predictions for each region, and use the select_random_points function to get the 500 random points for each region. We'll append the results to the lists we created in step 2

# %%
for target, predictions in zip(targets_valid, predictions_list):
    random_target, random_predictions = select_random_points(target, predictions)
    random_targets_valid.append(random_target)
    random_predictions_list.append(random_predictions)

# %% [markdown]
# print the number of points for each region to verify that we have 500 points for each

# %%
for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Region {i}: {len(random_target)} points")
# Out:
# Region 0: 500 points
# Region 1: 500 points
# Region 2: 500 points

# %% [markdown]
# use the bootstrap_resample_test function to analyze the top 200 wells from the 500 random points. You can replace the targets_valid and predictions_list variables in the loop with random_targets_valid and random_predictions_list when calling the bootstrap_resample_test function:

# %%
for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    bootstrap_resample_test(random_target, random_predictions, WELLS_FOR_DEVELOPMENT)
    print()
# Out:
# Checking Region 0:
# Repeating indices found in iteration 0: 130 unique indices instead of 200
# Repeating indices found in iteration 1: 130 unique indices instead of 200
# Repeating indices found in iteration 2: 125 unique indices instead of 200
# Repeating indices found in iteration 3: 130 unique indices instead of 200
# Repeating indices found in iteration 4: 125 unique indices instead of 200
# Repeating indices found in iteration 5: 128 unique indices instead of 200
# Repeating indices found in iteration 6: 125 unique indices instead of 200
# Repeating indices found in iteration 7: 133 unique indices instead of 200
# Repeating indices found in iteration 8: 139 unique indices instead of 200
# Repeating indices found in iteration 9: 128 unique indices instead of 200
# Repeating indices found in iteration 10: 130 unique indices instead of 200
# Repeating indices found in iteration 11: 125 unique indices instead of 200
# Repeating indices found in iteration 12: 133 unique indices instead of 200
# Repeating indices found in iteration 13: 128 unique indices instead of 200
# Repeating indices found in iteration 14: 132 unique indices instead of 200
# Repeating indices found in iteration 15: 127 unique indices instead of 200
# Repeating indices found in iteration 16: 123 unique indices instead of 200
# Repeating indices found in iteration 17: 124 unique indices instead of 200
# Repeating indices found in iteration 18: 136 unique indices instead of 200
# Repeating indices found in iteration 19: 125 unique indices instead of 200
# Repeating indices found in iteration 20: 123 unique indices instead of 200
# Repeating indices found in iteration 21: 125 unique indices instead of 200
# Repeating indices found in iteration 22: 125 unique indices instead of 200
# Repeating indices found in iteration 23: 123 unique indices instead of 200
# Repeating indices found in iteration 24: 128 unique indices instead of 200
# Repeating indices found in iteration 25: 124 unique indices instead of 200
# Repeating indices found in iteration 26: 126 unique indices instead of 200
# Repeating indices found in iteration 27: 123 unique indices instead of 200
# Repeating indices found in iteration 28: 129 unique indices instead of 200
# Repeating indices found in iteration 29: 129 unique indices instead of 200
# Repeating indices found in iteration 30: 123 unique indices instead of 200
# Repeating indices found in iteration 31: 128 unique indices instead of 200
# Repeating indices found in iteration 32: 131 unique indices instead of 200
# Repeating indices found in iteration 33: 125 unique indices instead of 200
# Repeating indices found in iteration 34: 120 unique indices instead of 200
# Repeating indices found in iteration 35: 131 unique indices instead of 200
# Repeating indices found in iteration 36: 132 unique indices instead of 200
# Repeating indices found in iteration 37: 122 unique indices instead of 200
# Repeating indices found in iteration 38: 124 unique indices instead of 200
# Repeating indices found in iteration 39: 120 unique indices instead of 200
# Repeating indices found in iteration 40: 125 unique indices instead of 200
# Repeating indices found in iteration 41: 130 unique indices instead of 200
# Repeating indices found in iteration 42: 128 unique indices instead of 200
# Repeating indices found in iteration 43: 119 unique indices instead of 200
# Repeating indices found in iteration 44: 135 unique indices instead of 200
# Repeating indices found in iteration 45: 126 unique indices instead of 200
# Repeating indices found in iteration 46: 127 unique indices instead of 200
# Repeating indices found in iteration 47: 138 unique indices instead of 200
# Repeating indices found in iteration 48: 124 unique indices instead of 200
# Repeating indices found in iteration 49: 123 unique indices instead of 200
# Repeating indices found in iteration 50: 135 unique indices instead of 200
# Repeating indices found in iteration 51: 132 unique indices instead of 200
# Repeating indices found in iteration 52: 117 unique indices instead of 200
# Repeating indices found in iteration 53: 129 unique indices instead of 200
# Repeating indices found in iteration 54: 123 unique indices instead of 200
# Repeating indices found in iteration 55: 133 unique indices instead of 200
# Repeating indices found in iteration 56: 124 unique indices instead of 200
# Repeating indices found in iteration 57: 123 unique indices instead of 200
# Repeating indices found in iteration 58: 121 unique indices instead of 200
# Repeating indices found in iteration 59: 115 unique indices instead of 200
# Repeating indices found in iteration 60: 127 unique indices instead of 200
# Repeating indices found in iteration 61: 121 unique indices instead of 200
# Repeating indices found in iteration 62: 128 unique indices instead of 200
# Repeating indices found in iteration 63: 121 unique indices instead of 200
# Repeating indices found in iteration 64: 135 unique indices instead of 200
# Repeating indices found in iteration 65: 124 unique indices instead of 200
# Repeating indices found in iteration 66: 121 unique indices instead of 200
# Repeating indices found in iteration 67: 131 unique indices instead of 200
# Repeating indices found in iteration 68: 135 unique indices instead of 200
# Repeating indices found in iteration 69: 123 unique indices instead of 200
# Repeating indices found in iteration 70: 131 unique indices instead of 200
# Repeating indices found in iteration 71: 123 unique indices instead of 200
# Repeating indices found in iteration 72: 127 unique indices instead of 200
# Repeating indices found in iteration 73: 130 unique indices instead of 200
# Repeating indices found in iteration 74: 125 unique indices instead of 200
# Repeating indices found in iteration 75: 134 unique indices instead of 200
# Repeating indices found in iteration 76: 129 unique indices instead of 200
# Repeating indices found in iteration 77: 127 unique indices instead of 200
# Repeating indices found in iteration 78: 128 unique indices instead of 200
# Repeating indices found in iteration 79: 119 unique indices instead of 200
# Repeating indices found in iteration 80: 141 unique indices instead of 200
# Repeating indices found in iteration 81: 128 unique indices instead of 200
# Repeating indices found in iteration 82: 135 unique indices instead of 200
# Repeating indices found in iteration 83: 123 unique indices instead of 200
# Repeating indices found in iteration 84: 128 unique indices instead of 200
# Repeating indices found in iteration 85: 129 unique indices instead of 200
# Repeating indices found in iteration 86: 121 unique indices instead of 200
# Repeating indices found in iteration 87: 121 unique indices instead of 200
# Repeating indices found in iteration 88: 129 unique indices instead of 200
# Repeating indices found in iteration 89: 124 unique indices instead of 200
# Repeating indices found in iteration 90: 129 unique indices instead of 200
# Repeating indices found in iteration 91: 121 unique indices instead of 200
# Repeating indices found in iteration 92: 120 unique indices instead of 200
# Repeating indices found in iteration 93: 116 unique indices instead of 200
# Repeating indices found in iteration 94: 126 unique indices instead of 200
# Repeating indices found in iteration 95: 127 unique indices instead of 200
# Repeating indices found in iteration 96: 129 unique indices instead of 200
# Repeating indices found in iteration 97: 124 unique indices instead of 200
# Repeating indices found in iteration 98: 141 unique indices instead of 200
# Repeating indices found in iteration 99: 126 unique indices instead of 200
#
# Checking Region 1:
# Repeating indices found in iteration 0: 124 unique indices instead of 200
# Repeating indices found in iteration 1: 133 unique indices instead of 200
# Repeating indices found in iteration 2: 126 unique indices instead of 200
# Repeating indices found in iteration 3: 133 unique indices instead of 200
# Repeating indices found in iteration 4: 129 unique indices instead of 200
# Repeating indices found in iteration 5: 132 unique indices instead of 200
# Repeating indices found in iteration 6: 123 unique indices instead of 200
# Repeating indices found in iteration 7: 125 unique indices instead of 200
# Repeating indices found in iteration 8: 135 unique indices instead of 200
# Repeating indices found in iteration 9: 127 unique indices instead of 200
# Repeating indices found in iteration 10: 132 unique indices instead of 200
# Repeating indices found in iteration 11: 129 unique indices instead of 200
# Repeating indices found in iteration 12: 137 unique indices instead of 200
# Repeating indices found in iteration 13: 129 unique indices instead of 200
# Repeating indices found in iteration 14: 116 unique indices instead of 200
# Repeating indices found in iteration 15: 120 unique indices instead of 200
# Repeating indices found in iteration 16: 122 unique indices instead of 200
# Repeating indices found in iteration 17: 125 unique indices instead of 200
# Repeating indices found in iteration 18: 131 unique indices instead of 200
# Repeating indices found in iteration 19: 134 unique indices instead of 200
# Repeating indices found in iteration 20: 127 unique indices instead of 200
# Repeating indices found in iteration 21: 114 unique indices instead of 200
# Repeating indices found in iteration 22: 125 unique indices instead of 200
# Repeating indices found in iteration 23: 124 unique indices instead of 200
# Repeating indices found in iteration 24: 125 unique indices instead of 200
# Repeating indices found in iteration 25: 120 unique indices instead of 200
# Repeating indices found in iteration 26: 124 unique indices instead of 200
# Repeating indices found in iteration 27: 131 unique indices instead of 200
# Repeating indices found in iteration 28: 123 unique indices instead of 200
# Repeating indices found in iteration 29: 128 unique indices instead of 200
# Repeating indices found in iteration 30: 122 unique indices instead of 200
# Repeating indices found in iteration 31: 124 unique indices instead of 200
# Repeating indices found in iteration 32: 140 unique indices instead of 200
# Repeating indices found in iteration 33: 125 unique indices instead of 200
# Repeating indices found in iteration 34: 121 unique indices instead of 200
# Repeating indices found in iteration 35: 127 unique indices instead of 200
# Repeating indices found in iteration 36: 128 unique indices instead of 200
# Repeating indices found in iteration 37: 134 unique indices instead of 200
# Repeating indices found in iteration 38: 132 unique indices instead of 200
# Repeating indices found in iteration 39: 123 unique indices instead of 200
# Repeating indices found in iteration 40: 130 unique indices instead of 200
# Repeating indices found in iteration 41: 133 unique indices instead of 200
# Repeating indices found in iteration 42: 128 unique indices instead of 200
# Repeating indices found in iteration 43: 136 unique indices instead of 200
# Repeating indices found in iteration 44: 128 unique indices instead of 200
# Repeating indices found in iteration 45: 124 unique indices instead of 200
# Repeating indices found in iteration 46: 119 unique indices instead of 200
# Repeating indices found in iteration 47: 128 unique indices instead of 200
# Repeating indices found in iteration 48: 127 unique indices instead of 200
# Repeating indices found in iteration 49: 130 unique indices instead of 200
# Repeating indices found in iteration 50: 129 unique indices instead of 200
# Repeating indices found in iteration 51: 116 unique indices instead of 200
# Repeating indices found in iteration 52: 115 unique indices instead of 200
# Repeating indices found in iteration 53: 133 unique indices instead of 200
# Repeating indices found in iteration 54: 135 unique indices instead of 200
# Repeating indices found in iteration 55: 122 unique indices instead of 200
# Repeating indices found in iteration 56: 122 unique indices instead of 200
# Repeating indices found in iteration 57: 120 unique indices instead of 200
# Repeating indices found in iteration 58: 121 unique indices instead of 200
# Repeating indices found in iteration 59: 121 unique indices instead of 200
# Repeating indices found in iteration 60: 137 unique indices instead of 200
# Repeating indices found in iteration 61: 143 unique indices instead of 200
# Repeating indices found in iteration 62: 124 unique indices instead of 200
# Repeating indices found in iteration 63: 130 unique indices instead of 200
# Repeating indices found in iteration 64: 116 unique indices instead of 200
# Repeating indices found in iteration 65: 132 unique indices instead of 200
# Repeating indices found in iteration 66: 125 unique indices instead of 200
# Repeating indices found in iteration 67: 133 unique indices instead of 200
# Repeating indices found in iteration 68: 133 unique indices instead of 200
# Repeating indices found in iteration 69: 130 unique indices instead of 200
# Repeating indices found in iteration 70: 122 unique indices instead of 200
# Repeating indices found in iteration 71: 114 unique indices instead of 200
# Repeating indices found in iteration 72: 123 unique indices instead of 200
# Repeating indices found in iteration 73: 127 unique indices instead of 200
# Repeating indices found in iteration 74: 128 unique indices instead of 200
# Repeating indices found in iteration 75: 124 unique indices instead of 200
# Repeating indices found in iteration 76: 130 unique indices instead of 200
# Repeating indices found in iteration 77: 127 unique indices instead of 200
# Repeating indices found in iteration 78: 134 unique indices instead of 200
# Repeating indices found in iteration 79: 129 unique indices instead of 200
# Repeating indices found in iteration 80: 123 unique indices instead of 200
# Repeating indices found in iteration 81: 126 unique indices instead of 200
# Repeating indices found in iteration 82: 120 unique indices instead of 200
# Repeating indices found in iteration 83: 127 unique indices instead of 200
# Repeating indices found in iteration 84: 130 unique indices instead of 200
# Repeating indices found in iteration 85: 122 unique indices instead of 200
# Repeating indices found in iteration 86: 136 unique indices instead of 200
# Repeating indices found in iteration 87: 129 unique indices instead of 200
# Repeating indices found in iteration 88: 121 unique indices instead of 200
# Repeating indices found in iteration 89: 134 unique indices instead of 200
# Repeating indices found in iteration 90: 124 unique indices instead of 200
# Repeating indices found in iteration 91: 121 unique indices instead of 200
# Repeating indices found in iteration 92: 125 unique indices instead of 200
# Repeating indices found in iteration 93: 132 unique indices instead of 200
# Repeating indices found in iteration 94: 124 unique indices instead of 200
# Repeating indices found in iteration 95: 122 unique indices instead of 200
# Repeating indices found in iteration 96: 134 unique indices instead of 200
# Repeating indices found in iteration 97: 125 unique indices instead of 200
# Repeating indices found in iteration 98: 128 unique indices instead of 200
# Repeating indices found in iteration 99: 120 unique indices instead of 200
#
# Checking Region 2:
# Repeating indices found in iteration 0: 131 unique indices instead of 200
# Repeating indices found in iteration 1: 121 unique indices instead of 200
# Repeating indices found in iteration 2: 134 unique indices instead of 200
# Repeating indices found in iteration 3: 131 unique indices instead of 200
# Repeating indices found in iteration 4: 133 unique indices instead of 200
# Repeating indices found in iteration 5: 132 unique indices instead of 200
# Repeating indices found in iteration 6: 127 unique indices instead of 200
# Repeating indices found in iteration 7: 127 unique indices instead of 200
# Repeating indices found in iteration 8: 133 unique indices instead of 200
# Repeating indices found in iteration 9: 131 unique indices instead of 200
# Repeating indices found in iteration 10: 122 unique indices instead of 200
# Repeating indices found in iteration 11: 126 unique indices instead of 200
# Repeating indices found in iteration 12: 139 unique indices instead of 200
# Repeating indices found in iteration 13: 124 unique indices instead of 200
# Repeating indices found in iteration 14: 121 unique indices instead of 200
# Repeating indices found in iteration 15: 131 unique indices instead of 200
# Repeating indices found in iteration 16: 127 unique indices instead of 200
# Repeating indices found in iteration 17: 126 unique indices instead of 200
# Repeating indices found in iteration 18: 121 unique indices instead of 200
# Repeating indices found in iteration 19: 132 unique indices instead of 200
# Repeating indices found in iteration 20: 119 unique indices instead of 200
# Repeating indices found in iteration 21: 134 unique indices instead of 200
# Repeating indices found in iteration 22: 123 unique indices instead of 200
# Repeating indices found in iteration 23: 128 unique indices instead of 200
# Repeating indices found in iteration 24: 133 unique indices instead of 200
# Repeating indices found in iteration 25: 127 unique indices instead of 200
# Repeating indices found in iteration 26: 125 unique indices instead of 200
# Repeating indices found in iteration 27: 127 unique indices instead of 200
# Repeating indices found in iteration 28: 130 unique indices instead of 200
# Repeating indices found in iteration 29: 120 unique indices instead of 200
# Repeating indices found in iteration 30: 131 unique indices instead of 200
# Repeating indices found in iteration 31: 130 unique indices instead of 200
# Repeating indices found in iteration 32: 124 unique indices instead of 200
# Repeating indices found in iteration 33: 122 unique indices instead of 200
# Repeating indices found in iteration 34: 128 unique indices instead of 200
# Repeating indices found in iteration 35: 125 unique indices instead of 200
# Repeating indices found in iteration 36: 127 unique indices instead of 200
# Repeating indices found in iteration 37: 131 unique indices instead of 200
# Repeating indices found in iteration 38: 134 unique indices instead of 200
# Repeating indices found in iteration 39: 125 unique indices instead of 200
# Repeating indices found in iteration 40: 122 unique indices instead of 200
# Repeating indices found in iteration 41: 132 unique indices instead of 200
# Repeating indices found in iteration 42: 120 unique indices instead of 200
# Repeating indices found in iteration 43: 126 unique indices instead of 200
# Repeating indices found in iteration 44: 128 unique indices instead of 200
# Repeating indices found in iteration 45: 128 unique indices instead of 200
# Repeating indices found in iteration 46: 127 unique indices instead of 200
# Repeating indices found in iteration 47: 127 unique indices instead of 200
# Repeating indices found in iteration 48: 125 unique indices instead of 200
# Repeating indices found in iteration 49: 126 unique indices instead of 200
# Repeating indices found in iteration 50: 128 unique indices instead of 200
# Repeating indices found in iteration 51: 120 unique indices instead of 200
# Repeating indices found in iteration 52: 137 unique indices instead of 200
# Repeating indices found in iteration 53: 122 unique indices instead of 200
# Repeating indices found in iteration 54: 117 unique indices instead of 200
# Repeating indices found in iteration 55: 125 unique indices instead of 200
# Repeating indices found in iteration 56: 125 unique indices instead of 200
# Repeating indices found in iteration 57: 135 unique indices instead of 200
# Repeating indices found in iteration 58: 117 unique indices instead of 200
# Repeating indices found in iteration 59: 128 unique indices instead of 200
# Repeating indices found in iteration 60: 132 unique indices instead of 200
# Repeating indices found in iteration 61: 130 unique indices instead of 200
# Repeating indices found in iteration 62: 126 unique indices instead of 200
# Repeating indices found in iteration 63: 131 unique indices instead of 200
# Repeating indices found in iteration 64: 128 unique indices instead of 200
# Repeating indices found in iteration 65: 126 unique indices instead of 200
# Repeating indices found in iteration 66: 135 unique indices instead of 200
# Repeating indices found in iteration 67: 125 unique indices instead of 200
# Repeating indices found in iteration 68: 125 unique indices instead of 200
# Repeating indices found in iteration 69: 121 unique indices instead of 200
# Repeating indices found in iteration 70: 130 unique indices instead of 200
# Repeating indices found in iteration 71: 119 unique indices instead of 200
# Repeating indices found in iteration 72: 121 unique indices instead of 200
# Repeating indices found in iteration 73: 122 unique indices instead of 200
# Repeating indices found in iteration 74: 123 unique indices instead of 200
# Repeating indices found in iteration 75: 127 unique indices instead of 200
# Repeating indices found in iteration 76: 126 unique indices instead of 200
# Repeating indices found in iteration 77: 127 unique indices instead of 200
# Repeating indices found in iteration 78: 119 unique indices instead of 200
# Repeating indices found in iteration 79: 129 unique indices instead of 200
# Repeating indices found in iteration 80: 116 unique indices instead of 200
# Repeating indices found in iteration 81: 114 unique indices instead of 200
# Repeating indices found in iteration 82: 121 unique indices instead of 200
# Repeating indices found in iteration 83: 141 unique indices instead of 200
# Repeating indices found in iteration 84: 126 unique indices instead of 200
# Repeating indices found in iteration 85: 121 unique indices instead of 200
# Repeating indices found in iteration 86: 130 unique indices instead of 200
# Repeating indices found in iteration 87: 128 unique indices instead of 200
# Repeating indices found in iteration 88: 124 unique indices instead of 200
# Repeating indices found in iteration 89: 119 unique indices instead of 200
# Repeating indices found in iteration 90: 128 unique indices instead of 200
# Repeating indices found in iteration 91: 129 unique indices instead of 200
# Repeating indices found in iteration 92: 130 unique indices instead of 200
# Repeating indices found in iteration 93: 121 unique indices instead of 200
# Repeating indices found in iteration 94: 124 unique indices instead of 200
# Repeating indices found in iteration 95: 130 unique indices instead of 200
# Repeating indices found in iteration 96: 136 unique indices instead of 200
# Repeating indices found in iteration 97: 128 unique indices instead of 200
# Repeating indices found in iteration 98: 133 unique indices instead of 200
# Repeating indices found in iteration 99: 125 unique indices instead of 200

# %% [markdown]
# ### Idea 1: Increase the number of iterations in the bootstrap_resample_test function:
# Increase the number of iterations by changing the n_iterations parameter when calling the function. For example, set it to 500: <br>

# %%
for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    bootstrap_resample_test(random_target, random_predictions, WELLS_FOR_DEVELOPMENT, n_iterations=500)
    print()
# Out:
# Checking Region 0:
# Repeating indices found in iteration 0: 130 unique indices instead of 200
# Repeating indices found in iteration 1: 120 unique indices instead of 200
# Repeating indices found in iteration 2: 132 unique indices instead of 200
# Repeating indices found in iteration 3: 114 unique indices instead of 200
# Repeating indices found in iteration 4: 124 unique indices instead of 200
# Repeating indices found in iteration 5: 128 unique indices instead of 200
# Repeating indices found in iteration 6: 122 unique indices instead of 200
# Repeating indices found in iteration 7: 127 unique indices instead of 200
# Repeating indices found in iteration 8: 130 unique indices instead of 200
# Repeating indices found in iteration 9: 130 unique indices instead of 200
# Repeating indices found in iteration 10: 123 unique indices instead of 200
# Repeating indices found in iteration 11: 127 unique indices instead of 200
# Repeating indices found in iteration 12: 122 unique indices instead of 200
# Repeating indices found in iteration 13: 126 unique indices instead of 200
# Repeating indices found in iteration 14: 128 unique indices instead of 200
# Repeating indices found in iteration 15: 134 unique indices instead of 200
# Repeating indices found in iteration 16: 123 unique indices instead of 200
# Repeating indices found in iteration 17: 126 unique indices instead of 200
# Repeating indices found in iteration 18: 131 unique indices instead of 200
# Repeating indices found in iteration 19: 128 unique indices instead of 200
# Repeating indices found in iteration 20: 122 unique indices instead of 200
# Repeating indices found in iteration 21: 125 unique indices instead of 200
# Repeating indices found in iteration 22: 118 unique indices instead of 200
# Repeating indices found in iteration 23: 126 unique indices instead of 200
# Repeating indices found in iteration 24: 130 unique indices instead of 200
# Repeating indices found in iteration 25: 119 unique indices instead of 200
# Repeating indices found in iteration 26: 124 unique indices instead of 200
# Repeating indices found in iteration 27: 126 unique indices instead of 200
# Repeating indices found in iteration 28: 131 unique indices instead of 200
# Repeating indices found in iteration 29: 123 unique indices instead of 200
# Repeating indices found in iteration 30: 123 unique indices instead of 200
# Repeating indices found in iteration 31: 126 unique indices instead of 200
# Repeating indices found in iteration 32: 123 unique indices instead of 200
# Repeating indices found in iteration 33: 124 unique indices instead of 200
# Repeating indices found in iteration 34: 131 unique indices instead of 200
# Repeating indices found in iteration 35: 122 unique indices instead of 200
# Repeating indices found in iteration 36: 125 unique indices instead of 200
# Repeating indices found in iteration 37: 129 unique indices instead of 200
# Repeating indices found in iteration 38: 138 unique indices instead of 200
# Repeating indices found in iteration 39: 127 unique indices instead of 200
# Repeating indices found in iteration 40: 128 unique indices instead of 200
# Repeating indices found in iteration 41: 128 unique indices instead of 200
# Repeating indices found in iteration 42: 123 unique indices instead of 200
# Repeating indices found in iteration 43: 125 unique indices instead of 200
# Repeating indices found in iteration 44: 124 unique indices instead of 200
# Repeating indices found in iteration 45: 130 unique indices instead of 200
# Repeating indices found in iteration 46: 115 unique indices instead of 200
# Repeating indices found in iteration 47: 128 unique indices instead of 200
# Repeating indices found in iteration 48: 132 unique indices instead of 200
# Repeating indices found in iteration 49: 129 unique indices instead of 200
# Repeating indices found in iteration 50: 133 unique indices instead of 200
# Repeating indices found in iteration 51: 134 unique indices instead of 200
# Repeating indices found in iteration 52: 122 unique indices instead of 200
# Repeating indices found in iteration 53: 130 unique indices instead of 200
# Repeating indices found in iteration 54: 118 unique indices instead of 200
# Repeating indices found in iteration 55: 127 unique indices instead of 200
# Repeating indices found in iteration 56: 126 unique indices instead of 200
# Repeating indices found in iteration 57: 130 unique indices instead of 200
# Repeating indices found in iteration 58: 122 unique indices instead of 200
# Repeating indices found in iteration 59: 127 unique indices instead of 200
# Repeating indices found in iteration 60: 123 unique indices instead of 200
# Repeating indices found in iteration 61: 119 unique indices instead of 200
# Repeating indices found in iteration 62: 118 unique indices instead of 200
# Repeating indices found in iteration 63: 124 unique indices instead of 200
# Repeating indices found in iteration 64: 130 unique indices instead of 200
# Repeating indices found in iteration 65: 129 unique indices instead of 200
# Repeating indices found in iteration 66: 124 unique indices instead of 200
# Repeating indices found in iteration 67: 130 unique indices instead of 200
# Repeating indices found in iteration 68: 129 unique indices instead of 200
# Repeating indices found in iteration 69: 128 unique indices instead of 200
# Repeating indices found in iteration 70: 126 unique indices instead of 200
# Repeating indices found in iteration 71: 130 unique indices instead of 200
# Repeating indices found in iteration 72: 121 unique indices instead of 200
# Repeating indices found in iteration 73: 118 unique indices instead of 200
# Repeating indices found in iteration 74: 130 unique indices instead of 200
# Repeating indices found in iteration 75: 133 unique indices instead of 200
# Repeating indices found in iteration 76: 131 unique indices instead of 200
# Repeating indices found in iteration 77: 124 unique indices instead of 200
# Repeating indices found in iteration 78: 129 unique indices instead of 200
# Repeating indices found in iteration 79: 120 unique indices instead of 200
# Repeating indices found in iteration 80: 126 unique indices instead of 200
# Repeating indices found in iteration 81: 122 unique indices instead of 200
# Repeating indices found in iteration 82: 120 unique indices instead of 200
# Repeating indices found in iteration 83: 121 unique indices instead of 200
# Repeating indices found in iteration 84: 130 unique indices instead of 200
# Repeating indices found in iteration 85: 124 unique indices instead of 200
# Repeating indices found in iteration 86: 122 unique indices instead of 200
# Repeating indices found in iteration 87: 129 unique indices instead of 200
# Repeating indices found in iteration 88: 129 unique indices instead of 200
# Repeating indices found in iteration 89: 127 unique indices instead of 200
# Repeating indices found in iteration 90: 136 unique indices instead of 200
# Repeating indices found in iteration 91: 132 unique indices instead of 200
# Repeating indices found in iteration 92: 133 unique indices instead of 200
# Repeating indices found in iteration 93: 132 unique indices instead of 200
# Repeating indices found in iteration 94: 124 unique indices instead of 200
# Repeating indices found in iteration 95: 126 unique indices instead of 200
# Repeating indices found in iteration 96: 122 unique indices instead of 200
# Repeating indices found in iteration 97: 122 unique indices instead of 200
# Repeating indices found in iteration 98: 130 unique indices instead of 200
# Repeating indices found in iteration 99: 129 unique indices instead of 200
# Repeating indices found in iteration 100: 124 unique indices instead of 200
# Repeating indices found in iteration 101: 120 unique indices instead of 200
# Repeating indices found in iteration 102: 123 unique indices instead of 200
# Repeating indices found in iteration 103: 127 unique indices instead of 200
# Repeating indices found in iteration 104: 118 unique indices instead of 200
# Repeating indices found in iteration 105: 125 unique indices instead of 200
# Repeating indices found in iteration 106: 125 unique indices instead of 200
# Repeating indices found in iteration 107: 136 unique indices instead of 200
# Repeating indices found in iteration 108: 137 unique indices instead of 200
# Repeating indices found in iteration 109: 127 unique indices instead of 200
# Repeating indices found in iteration 110: 116 unique indices instead of 200
# Repeating indices found in iteration 111: 124 unique indices instead of 200
# Repeating indices found in iteration 112: 130 unique indices instead of 200
# Repeating indices found in iteration 113: 131 unique indices instead of 200
# Repeating indices found in iteration 114: 126 unique indices instead of 200
# Repeating indices found in iteration 115: 119 unique indices instead of 200
# Repeating indices found in iteration 116: 114 unique indices instead of 200
# Repeating indices found in iteration 117: 124 unique indices instead of 200
# Repeating indices found in iteration 118: 117 unique indices instead of 200
# Repeating indices found in iteration 119: 131 unique indices instead of 200
# Repeating indices found in iteration 120: 131 unique indices instead of 200
# Repeating indices found in iteration 121: 127 unique indices instead of 200
# Repeating indices found in iteration 122: 118 unique indices instead of 200
# Repeating indices found in iteration 123: 119 unique indices instead of 200
# Repeating indices found in iteration 124: 134 unique indices instead of 200
# Repeating indices found in iteration 125: 118 unique indices instead of 200
# Repeating indices found in iteration 126: 119 unique indices instead of 200
# Repeating indices found in iteration 127: 138 unique indices instead of 200
# Repeating indices found in iteration 128: 128 unique indices instead of 200
# Repeating indices found in iteration 129: 123 unique indices instead of 200
# Repeating indices found in iteration 130: 126 unique indices instead of 200
# Repeating indices found in iteration 131: 137 unique indices instead of 200
# Repeating indices found in iteration 132: 124 unique indices instead of 200
# Repeating indices found in iteration 133: 127 unique indices instead of 200
# Repeating indices found in iteration 134: 126 unique indices instead of 200
# Repeating indices found in iteration 135: 126 unique indices instead of 200
# Repeating indices found in iteration 136: 116 unique indices instead of 200
# Repeating indices found in iteration 137: 131 unique indices instead of 200
# Repeating indices found in iteration 138: 124 unique indices instead of 200
# Repeating indices found in iteration 139: 123 unique indices instead of 200
# Repeating indices found in iteration 140: 132 unique indices instead of 200
# Repeating indices found in iteration 141: 131 unique indices instead of 200
# Repeating indices found in iteration 142: 119 unique indices instead of 200
# Repeating indices found in iteration 143: 123 unique indices instead of 200
# Repeating indices found in iteration 144: 119 unique indices instead of 200
# Repeating indices found in iteration 145: 124 unique indices instead of 200
# Repeating indices found in iteration 146: 129 unique indices instead of 200
# Repeating indices found in iteration 147: 123 unique indices instead of 200
# Repeating indices found in iteration 148: 135 unique indices instead of 200
# Repeating indices found in iteration 149: 120 unique indices instead of 200
# Repeating indices found in iteration 150: 122 unique indices instead of 200
# Repeating indices found in iteration 151: 129 unique indices instead of 200
# Repeating indices found in iteration 152: 129 unique indices instead of 200
# Repeating indices found in iteration 153: 127 unique indices instead of 200
# Repeating indices found in iteration 154: 123 unique indices instead of 200
# Repeating indices found in iteration 155: 132 unique indices instead of 200
# Repeating indices found in iteration 156: 135 unique indices instead of 200
# Repeating indices found in iteration 157: 127 unique indices instead of 200
# Repeating indices found in iteration 158: 125 unique indices instead of 200
# Repeating indices found in iteration 159: 127 unique indices instead of 200
# Repeating indices found in iteration 160: 124 unique indices instead of 200
# Repeating indices found in iteration 161: 129 unique indices instead of 200
# Repeating indices found in iteration 162: 122 unique indices instead of 200
# Repeating indices found in iteration 163: 136 unique indices instead of 200
# Repeating indices found in iteration 164: 128 unique indices instead of 200
# Repeating indices found in iteration 165: 128 unique indices instead of 200
# Repeating indices found in iteration 166: 124 unique indices instead of 200
# Repeating indices found in iteration 167: 126 unique indices instead of 200
# Repeating indices found in iteration 168: 134 unique indices instead of 200
# Repeating indices found in iteration 169: 129 unique indices instead of 200
# Repeating indices found in iteration 170: 127 unique indices instead of 200
# Repeating indices found in iteration 171: 131 unique indices instead of 200
# Repeating indices found in iteration 172: 121 unique indices instead of 200
# Repeating indices found in iteration 173: 129 unique indices instead of 200
# Repeating indices found in iteration 174: 128 unique indices instead of 200
# Repeating indices found in iteration 175: 134 unique indices instead of 200
# Repeating indices found in iteration 176: 122 unique indices instead of 200
# Repeating indices found in iteration 177: 116 unique indices instead of 200
# Repeating indices found in iteration 178: 132 unique indices instead of 200
# Repeating indices found in iteration 179: 129 unique indices instead of 200
# Repeating indices found in iteration 180: 140 unique indices instead of 200
# Repeating indices found in iteration 181: 133 unique indices instead of 200
# Repeating indices found in iteration 182: 120 unique indices instead of 200
# Repeating indices found in iteration 183: 130 unique indices instead of 200
# Repeating indices found in iteration 184: 126 unique indices instead of 200
# Repeating indices found in iteration 185: 135 unique indices instead of 200
# Repeating indices found in iteration 186: 124 unique indices instead of 200
# Repeating indices found in iteration 187: 125 unique indices instead of 200
# Repeating indices found in iteration 188: 118 unique indices instead of 200
# Repeating indices found in iteration 189: 125 unique indices instead of 200
# Repeating indices found in iteration 190: 134 unique indices instead of 200
# Repeating indices found in iteration 191: 122 unique indices instead of 200
# Repeating indices found in iteration 192: 125 unique indices instead of 200
# Repeating indices found in iteration 193: 132 unique indices instead of 200
# Repeating indices found in iteration 194: 125 unique indices instead of 200
# Repeating indices found in iteration 195: 120 unique indices instead of 200
# Repeating indices found in iteration 196: 122 unique indices instead of 200
# Repeating indices found in iteration 197: 127 unique indices instead of 200
# Repeating indices found in iteration 198: 121 unique indices instead of 200
# Repeating indices found in iteration 199: 113 unique indices instead of 200
# Repeating indices found in iteration 200: 121 unique indices instead of 200
# Repeating indices found in iteration 201: 125 unique indices instead of 200
# Repeating indices found in iteration 202: 129 unique indices instead of 200
# Repeating indices found in iteration 203: 126 unique indices instead of 200
# Repeating indices found in iteration 204: 132 unique indices instead of 200
# Repeating indices found in iteration 205: 128 unique indices instead of 200
# Repeating indices found in iteration 206: 131 unique indices instead of 200
# Repeating indices found in iteration 207: 133 unique indices instead of 200
# Repeating indices found in iteration 208: 119 unique indices instead of 200
# Repeating indices found in iteration 209: 118 unique indices instead of 200
# Repeating indices found in iteration 210: 125 unique indices instead of 200
# Repeating indices found in iteration 211: 128 unique indices instead of 200
# Repeating indices found in iteration 212: 135 unique indices instead of 200
# Repeating indices found in iteration 213: 130 unique indices instead of 200
# Repeating indices found in iteration 214: 119 unique indices instead of 200
# Repeating indices found in iteration 215: 138 unique indices instead of 200
# Repeating indices found in iteration 216: 131 unique indices instead of 200
# Repeating indices found in iteration 217: 127 unique indices instead of 200
# Repeating indices found in iteration 218: 128 unique indices instead of 200
# Repeating indices found in iteration 219: 122 unique indices instead of 200
# Repeating indices found in iteration 220: 126 unique indices instead of 200
# Repeating indices found in iteration 221: 129 unique indices instead of 200
# Repeating indices found in iteration 222: 135 unique indices instead of 200
# Repeating indices found in iteration 223: 128 unique indices instead of 200
# Repeating indices found in iteration 224: 127 unique indices instead of 200
# Repeating indices found in iteration 225: 130 unique indices instead of 200
# Repeating indices found in iteration 226: 128 unique indices instead of 200
# Repeating indices found in iteration 227: 135 unique indices instead of 200
# Repeating indices found in iteration 228: 126 unique indices instead of 200
# Repeating indices found in iteration 229: 124 unique indices instead of 200
# Repeating indices found in iteration 230: 130 unique indices instead of 200
# Repeating indices found in iteration 231: 126 unique indices instead of 200
# Repeating indices found in iteration 232: 121 unique indices instead of 200
# Repeating indices found in iteration 233: 124 unique indices instead of 200
# Repeating indices found in iteration 234: 134 unique indices instead of 200
# Repeating indices found in iteration 235: 132 unique indices instead of 200
# Repeating indices found in iteration 236: 131 unique indices instead of 200
# Repeating indices found in iteration 237: 129 unique indices instead of 200
# Repeating indices found in iteration 238: 133 unique indices instead of 200
# Repeating indices found in iteration 239: 125 unique indices instead of 200
# Repeating indices found in iteration 240: 129 unique indices instead of 200
# Repeating indices found in iteration 241: 121 unique indices instead of 200
# Repeating indices found in iteration 242: 129 unique indices instead of 200
# Repeating indices found in iteration 243: 125 unique indices instead of 200
# Repeating indices found in iteration 244: 131 unique indices instead of 200
# Repeating indices found in iteration 245: 137 unique indices instead of 200
# Repeating indices found in iteration 246: 122 unique indices instead of 200
# Repeating indices found in iteration 247: 116 unique indices instead of 200
# Repeating indices found in iteration 248: 120 unique indices instead of 200
# Repeating indices found in iteration 249: 125 unique indices instead of 200
# Repeating indices found in iteration 250: 127 unique indices instead of 200
# Repeating indices found in iteration 251: 119 unique indices instead of 200
# Repeating indices found in iteration 252: 125 unique indices instead of 200
# Repeating indices found in iteration 253: 123 unique indices instead of 200
# Repeating indices found in iteration 254: 130 unique indices instead of 200
# Repeating indices found in iteration 255: 128 unique indices instead of 200
# Repeating indices found in iteration 256: 139 unique indices instead of 200
# Repeating indices found in iteration 257: 125 unique indices instead of 200
# Repeating indices found in iteration 258: 134 unique indices instead of 200
# Repeating indices found in iteration 259: 125 unique indices instead of 200
# Repeating indices found in iteration 260: 125 unique indices instead of 200
# Repeating indices found in iteration 261: 132 unique indices instead of 200
# Repeating indices found in iteration 262: 131 unique indices instead of 200
# Repeating indices found in iteration 263: 129 unique indices instead of 200
# Repeating indices found in iteration 264: 133 unique indices instead of 200
# Repeating indices found in iteration 265: 123 unique indices instead of 200
# Repeating indices found in iteration 266: 130 unique indices instead of 200
# Repeating indices found in iteration 267: 136 unique indices instead of 200
# Repeating indices found in iteration 268: 123 unique indices instead of 200
# Repeating indices found in iteration 269: 134 unique indices instead of 200
# Repeating indices found in iteration 270: 117 unique indices instead of 200
# Repeating indices found in iteration 271: 125 unique indices instead of 200
# Repeating indices found in iteration 272: 121 unique indices instead of 200
# Repeating indices found in iteration 273: 123 unique indices instead of 200
# Repeating indices found in iteration 274: 121 unique indices instead of 200
# Repeating indices found in iteration 275: 124 unique indices instead of 200
# Repeating indices found in iteration 276: 130 unique indices instead of 200
# Repeating indices found in iteration 277: 136 unique indices instead of 200
# Repeating indices found in iteration 278: 127 unique indices instead of 200
# Repeating indices found in iteration 279: 129 unique indices instead of 200
# Repeating indices found in iteration 280: 129 unique indices instead of 200
# Repeating indices found in iteration 281: 136 unique indices instead of 200
# Repeating indices found in iteration 282: 125 unique indices instead of 200
# Repeating indices found in iteration 283: 120 unique indices instead of 200
# Repeating indices found in iteration 284: 121 unique indices instead of 200
# Repeating indices found in iteration 285: 135 unique indices instead of 200
# Repeating indices found in iteration 286: 113 unique indices instead of 200
# Repeating indices found in iteration 287: 116 unique indices instead of 200
# Repeating indices found in iteration 288: 123 unique indices instead of 200
# Repeating indices found in iteration 289: 120 unique indices instead of 200
# Repeating indices found in iteration 290: 127 unique indices instead of 200
# Repeating indices found in iteration 291: 130 unique indices instead of 200
# Repeating indices found in iteration 292: 126 unique indices instead of 200
# Repeating indices found in iteration 293: 116 unique indices instead of 200
# Repeating indices found in iteration 294: 124 unique indices instead of 200
# Repeating indices found in iteration 295: 124 unique indices instead of 200
# Repeating indices found in iteration 296: 126 unique indices instead of 200
# Repeating indices found in iteration 297: 128 unique indices instead of 200
# Repeating indices found in iteration 298: 131 unique indices instead of 200
# Repeating indices found in iteration 299: 123 unique indices instead of 200
# Repeating indices found in iteration 300: 134 unique indices instead of 200
# Repeating indices found in iteration 301: 134 unique indices instead of 200
# Repeating indices found in iteration 302: 121 unique indices instead of 200
# Repeating indices found in iteration 303: 121 unique indices instead of 200
# Repeating indices found in iteration 304: 118 unique indices instead of 200
# Repeating indices found in iteration 305: 122 unique indices instead of 200
# Repeating indices found in iteration 306: 134 unique indices instead of 200
# Repeating indices found in iteration 307: 116 unique indices instead of 200
# Repeating indices found in iteration 308: 128 unique indices instead of 200
# Repeating indices found in iteration 309: 146 unique indices instead of 200
# Repeating indices found in iteration 310: 136 unique indices instead of 200
# Repeating indices found in iteration 311: 124 unique indices instead of 200
# Repeating indices found in iteration 312: 126 unique indices instead of 200
# Repeating indices found in iteration 313: 132 unique indices instead of 200
# Repeating indices found in iteration 314: 128 unique indices instead of 200
# Repeating indices found in iteration 315: 136 unique indices instead of 200
# Repeating indices found in iteration 316: 125 unique indices instead of 200
# Repeating indices found in iteration 317: 127 unique indices instead of 200
# Repeating indices found in iteration 318: 133 unique indices instead of 200
# Repeating indices found in iteration 319: 120 unique indices instead of 200
# Repeating indices found in iteration 320: 136 unique indices instead of 200
# Repeating indices found in iteration 321: 126 unique indices instead of 200
# Repeating indices found in iteration 322: 131 unique indices instead of 200
# Repeating indices found in iteration 323: 120 unique indices instead of 200
# Repeating indices found in iteration 324: 122 unique indices instead of 200
# Repeating indices found in iteration 325: 127 unique indices instead of 200
# Repeating indices found in iteration 326: 134 unique indices instead of 200
# Repeating indices found in iteration 327: 134 unique indices instead of 200
# Repeating indices found in iteration 328: 124 unique indices instead of 200
# Repeating indices found in iteration 329: 125 unique indices instead of 200
# Repeating indices found in iteration 330: 123 unique indices instead of 200
# Repeating indices found in iteration 331: 129 unique indices instead of 200
# Repeating indices found in iteration 332: 129 unique indices instead of 200
# Repeating indices found in iteration 333: 128 unique indices instead of 200
# Repeating indices found in iteration 334: 124 unique indices instead of 200
# Repeating indices found in iteration 335: 132 unique indices instead of 200
# Repeating indices found in iteration 336: 128 unique indices instead of 200
# Repeating indices found in iteration 337: 130 unique indices instead of 200
# Repeating indices found in iteration 338: 124 unique indices instead of 200
# Repeating indices found in iteration 339: 128 unique indices instead of 200
# Repeating indices found in iteration 340: 127 unique indices instead of 200
# Repeating indices found in iteration 341: 135 unique indices instead of 200
# Repeating indices found in iteration 342: 136 unique indices instead of 200
# Repeating indices found in iteration 343: 129 unique indices instead of 200
# Repeating indices found in iteration 344: 130 unique indices instead of 200
# Repeating indices found in iteration 345: 131 unique indices instead of 200
# Repeating indices found in iteration 346: 128 unique indices instead of 200
# Repeating indices found in iteration 347: 125 unique indices instead of 200
# Repeating indices found in iteration 348: 119 unique indices instead of 200
# Repeating indices found in iteration 349: 132 unique indices instead of 200
# Repeating indices found in iteration 350: 127 unique indices instead of 200
# Repeating indices found in iteration 351: 132 unique indices instead of 200
# Repeating indices found in iteration 352: 127 unique indices instead of 200
# Repeating indices found in iteration 353: 121 unique indices instead of 200
# Repeating indices found in iteration 354: 130 unique indices instead of 200
# Repeating indices found in iteration 355: 118 unique indices instead of 200
# Repeating indices found in iteration 356: 125 unique indices instead of 200
# Repeating indices found in iteration 357: 125 unique indices instead of 200
# Repeating indices found in iteration 358: 125 unique indices instead of 200
# Repeating indices found in iteration 359: 122 unique indices instead of 200
# Repeating indices found in iteration 360: 126 unique indices instead of 200
# Repeating indices found in iteration 361: 127 unique indices instead of 200
# Repeating indices found in iteration 362: 129 unique indices instead of 200
# Repeating indices found in iteration 363: 120 unique indices instead of 200
# Repeating indices found in iteration 364: 123 unique indices instead of 200
# Repeating indices found in iteration 365: 132 unique indices instead of 200
# Repeating indices found in iteration 366: 133 unique indices instead of 200
# Repeating indices found in iteration 367: 131 unique indices instead of 200
# Repeating indices found in iteration 368: 123 unique indices instead of 200
# Repeating indices found in iteration 369: 128 unique indices instead of 200
# Repeating indices found in iteration 370: 133 unique indices instead of 200
# Repeating indices found in iteration 371: 127 unique indices instead of 200
# Repeating indices found in iteration 372: 120 unique indices instead of 200
# Repeating indices found in iteration 373: 120 unique indices instead of 200
# Repeating indices found in iteration 374: 128 unique indices instead of 200
# Repeating indices found in iteration 375: 121 unique indices instead of 200
# Repeating indices found in iteration 376: 132 unique indices instead of 200
# Repeating indices found in iteration 377: 130 unique indices instead of 200
# Repeating indices found in iteration 378: 128 unique indices instead of 200
# Repeating indices found in iteration 379: 123 unique indices instead of 200
# Repeating indices found in iteration 380: 132 unique indices instead of 200
# Repeating indices found in iteration 381: 134 unique indices instead of 200
# Repeating indices found in iteration 382: 128 unique indices instead of 200
# Repeating indices found in iteration 383: 125 unique indices instead of 200
# Repeating indices found in iteration 384: 129 unique indices instead of 200
# Repeating indices found in iteration 385: 131 unique indices instead of 200
# Repeating indices found in iteration 386: 125 unique indices instead of 200
# Repeating indices found in iteration 387: 124 unique indices instead of 200
# Repeating indices found in iteration 388: 128 unique indices instead of 200
# Repeating indices found in iteration 389: 124 unique indices instead of 200
# Repeating indices found in iteration 390: 125 unique indices instead of 200
# Repeating indices found in iteration 391: 131 unique indices instead of 200
# Repeating indices found in iteration 392: 135 unique indices instead of 200
# Repeating indices found in iteration 393: 125 unique indices instead of 200
# Repeating indices found in iteration 394: 129 unique indices instead of 200
# Repeating indices found in iteration 395: 130 unique indices instead of 200
# Repeating indices found in iteration 396: 136 unique indices instead of 200
# Repeating indices found in iteration 397: 128 unique indices instead of 200
# Repeating indices found in iteration 398: 128 unique indices instead of 200
# Repeating indices found in iteration 399: 131 unique indices instead of 200
# Repeating indices found in iteration 400: 140 unique indices instead of 200
# Repeating indices found in iteration 401: 126 unique indices instead of 200
# Repeating indices found in iteration 402: 128 unique indices instead of 200
# Repeating indices found in iteration 403: 120 unique indices instead of 200
# Repeating indices found in iteration 404: 126 unique indices instead of 200
# Repeating indices found in iteration 405: 123 unique indices instead of 200
# Repeating indices found in iteration 406: 132 unique indices instead of 200
# Repeating indices found in iteration 407: 123 unique indices instead of 200
# Repeating indices found in iteration 408: 134 unique indices instead of 200
# Repeating indices found in iteration 409: 123 unique indices instead of 200
# Repeating indices found in iteration 410: 129 unique indices instead of 200
# Repeating indices found in iteration 411: 128 unique indices instead of 200
# Repeating indices found in iteration 412: 125 unique indices instead of 200
# Repeating indices found in iteration 413: 138 unique indices instead of 200
# Repeating indices found in iteration 414: 129 unique indices instead of 200
# Repeating indices found in iteration 415: 128 unique indices instead of 200
# Repeating indices found in iteration 416: 129 unique indices instead of 200
# Repeating indices found in iteration 417: 129 unique indices instead of 200
# Repeating indices found in iteration 418: 129 unique indices instead of 200
# Repeating indices found in iteration 419: 128 unique indices instead of 200
# Repeating indices found in iteration 420: 124 unique indices instead of 200
# Repeating indices found in iteration 421: 125 unique indices instead of 200
# Repeating indices found in iteration 422: 129 unique indices instead of 200
# Repeating indices found in iteration 423: 124 unique indices instead of 200
# Repeating indices found in iteration 424: 137 unique indices instead of 200
# Repeating indices found in iteration 425: 124 unique indices instead of 200
# Repeating indices found in iteration 426: 130 unique indices instead of 200
# Repeating indices found in iteration 427: 116 unique indices instead of 200
# Repeating indices found in iteration 428: 132 unique indices instead of 200
# Repeating indices found in iteration 429: 116 unique indices instead of 200
# Repeating indices found in iteration 430: 127 unique indices instead of 200
# Repeating indices found in iteration 431: 115 unique indices instead of 200
# Repeating indices found in iteration 432: 130 unique indices instead of 200
# Repeating indices found in iteration 433: 131 unique indices instead of 200
# Repeating indices found in iteration 434: 145 unique indices instead of 200
# Repeating indices found in iteration 435: 134 unique indices instead of 200
# Repeating indices found in iteration 436: 139 unique indices instead of 200
# Repeating indices found in iteration 437: 133 unique indices instead of 200
# Repeating indices found in iteration 438: 127 unique indices instead of 200
# Repeating indices found in iteration 439: 128 unique indices instead of 200
# Repeating indices found in iteration 440: 128 unique indices instead of 200
# Repeating indices found in iteration 441: 132 unique indices instead of 200
# Repeating indices found in iteration 442: 130 unique indices instead of 200
# Repeating indices found in iteration 443: 127 unique indices instead of 200
# Repeating indices found in iteration 444: 131 unique indices instead of 200
# Repeating indices found in iteration 445: 128 unique indices instead of 200
# Repeating indices found in iteration 446: 120 unique indices instead of 200
# Repeating indices found in iteration 447: 127 unique indices instead of 200
# Repeating indices found in iteration 448: 123 unique indices instead of 200
# Repeating indices found in iteration 449: 134 unique indices instead of 200
# Repeating indices found in iteration 450: 127 unique indices instead of 200
# Repeating indices found in iteration 451: 124 unique indices instead of 200
# Repeating indices found in iteration 452: 117 unique indices instead of 200
# Repeating indices found in iteration 453: 119 unique indices instead of 200
# Repeating indices found in iteration 454: 127 unique indices instead of 200
# Repeating indices found in iteration 455: 138 unique indices instead of 200
# Repeating indices found in iteration 456: 127 unique indices instead of 200
# Repeating indices found in iteration 457: 123 unique indices instead of 200
# Repeating indices found in iteration 458: 127 unique indices instead of 200
# Repeating indices found in iteration 459: 121 unique indices instead of 200
# Repeating indices found in iteration 460: 129 unique indices instead of 200
# Repeating indices found in iteration 461: 126 unique indices instead of 200
# Repeating indices found in iteration 462: 130 unique indices instead of 200
# Repeating indices found in iteration 463: 128 unique indices instead of 200
# Repeating indices found in iteration 464: 135 unique indices instead of 200
# Repeating indices found in iteration 465: 133 unique indices instead of 200
# Repeating indices found in iteration 466: 128 unique indices instead of 200
# Repeating indices found in iteration 467: 124 unique indices instead of 200
# Repeating indices found in iteration 468: 120 unique indices instead of 200
# Repeating indices found in iteration 469: 131 unique indices instead of 200
# Repeating indices found in iteration 470: 123 unique indices instead of 200
# Repeating indices found in iteration 471: 127 unique indices instead of 200
# Repeating indices found in iteration 472: 127 unique indices instead of 200
# Repeating indices found in iteration 473: 126 unique indices instead of 200
# Repeating indices found in iteration 474: 124 unique indices instead of 200
# Repeating indices found in iteration 475: 131 unique indices instead of 200
# Repeating indices found in iteration 476: 121 unique indices instead of 200
# Repeating indices found in iteration 477: 120 unique indices instead of 200
# Repeating indices found in iteration 478: 128 unique indices instead of 200
# Repeating indices found in iteration 479: 125 unique indices instead of 200
# Repeating indices found in iteration 480: 122 unique indices instead of 200
# Repeating indices found in iteration 481: 123 unique indices instead of 200
# Repeating indices found in iteration 482: 124 unique indices instead of 200
# Repeating indices found in iteration 483: 131 unique indices instead of 200
# Repeating indices found in iteration 484: 124 unique indices instead of 200
# Repeating indices found in iteration 485: 126 unique indices instead of 200
# Repeating indices found in iteration 486: 125 unique indices instead of 200
# Repeating indices found in iteration 487: 125 unique indices instead of 200
# Repeating indices found in iteration 488: 133 unique indices instead of 200
# Repeating indices found in iteration 489: 120 unique indices instead of 200
# Repeating indices found in iteration 490: 127 unique indices instead of 200
# Repeating indices found in iteration 491: 119 unique indices instead of 200
# Repeating indices found in iteration 492: 128 unique indices instead of 200
# Repeating indices found in iteration 493: 130 unique indices instead of 200
# Repeating indices found in iteration 494: 124 unique indices instead of 200
# Repeating indices found in iteration 495: 133 unique indices instead of 200
# Repeating indices found in iteration 496: 130 unique indices instead of 200
# Repeating indices found in iteration 497: 130 unique indices instead of 200
# Repeating indices found in iteration 498: 128 unique indices instead of 200
# Repeating indices found in iteration 499: 126 unique indices instead of 200
#
# Checking Region 1:
# Repeating indices found in iteration 0: 130 unique indices instead of 200
# Repeating indices found in iteration 1: 129 unique indices instead of 200
# Repeating indices found in iteration 2: 119 unique indices instead of 200
# Repeating indices found in iteration 3: 128 unique indices instead of 200
# Repeating indices found in iteration 4: 132 unique indices instead of 200
# Repeating indices found in iteration 5: 122 unique indices instead of 200
# Repeating indices found in iteration 6: 128 unique indices instead of 200
# Repeating indices found in iteration 7: 128 unique indices instead of 200
# Repeating indices found in iteration 8: 130 unique indices instead of 200
# Repeating indices found in iteration 9: 128 unique indices instead of 200
# Repeating indices found in iteration 10: 129 unique indices instead of 200
# Repeating indices found in iteration 11: 126 unique indices instead of 200
# Repeating indices found in iteration 12: 125 unique indices instead of 200
# Repeating indices found in iteration 13: 134 unique indices instead of 200
# Repeating indices found in iteration 14: 131 unique indices instead of 200
# Repeating indices found in iteration 15: 128 unique indices instead of 200
# Repeating indices found in iteration 16: 124 unique indices instead of 200
# Repeating indices found in iteration 17: 126 unique indices instead of 200
# Repeating indices found in iteration 18: 121 unique indices instead of 200
# Repeating indices found in iteration 19: 133 unique indices instead of 200
# Repeating indices found in iteration 20: 132 unique indices instead of 200
# Repeating indices found in iteration 21: 116 unique indices instead of 200
# Repeating indices found in iteration 22: 125 unique indices instead of 200
# Repeating indices found in iteration 23: 125 unique indices instead of 200
# Repeating indices found in iteration 24: 128 unique indices instead of 200
# Repeating indices found in iteration 25: 136 unique indices instead of 200
# Repeating indices found in iteration 26: 125 unique indices instead of 200
# Repeating indices found in iteration 27: 124 unique indices instead of 200
# Repeating indices found in iteration 28: 127 unique indices instead of 200
# Repeating indices found in iteration 29: 134 unique indices instead of 200
# Repeating indices found in iteration 30: 129 unique indices instead of 200
# Repeating indices found in iteration 31: 124 unique indices instead of 200
# Repeating indices found in iteration 32: 121 unique indices instead of 200
# Repeating indices found in iteration 33: 121 unique indices instead of 200
# Repeating indices found in iteration 34: 113 unique indices instead of 200
# Repeating indices found in iteration 35: 130 unique indices instead of 200
# Repeating indices found in iteration 36: 134 unique indices instead of 200
# Repeating indices found in iteration 37: 135 unique indices instead of 200
# Repeating indices found in iteration 38: 134 unique indices instead of 200
# Repeating indices found in iteration 39: 126 unique indices instead of 200
# Repeating indices found in iteration 40: 127 unique indices instead of 200
# Repeating indices found in iteration 41: 127 unique indices instead of 200
# Repeating indices found in iteration 42: 136 unique indices instead of 200
# Repeating indices found in iteration 43: 130 unique indices instead of 200
# Repeating indices found in iteration 44: 127 unique indices instead of 200
# Repeating indices found in iteration 45: 133 unique indices instead of 200
# Repeating indices found in iteration 46: 130 unique indices instead of 200
# Repeating indices found in iteration 47: 132 unique indices instead of 200
# Repeating indices found in iteration 48: 123 unique indices instead of 200
# Repeating indices found in iteration 49: 135 unique indices instead of 200
# Repeating indices found in iteration 50: 121 unique indices instead of 200
# Repeating indices found in iteration 51: 130 unique indices instead of 200
# Repeating indices found in iteration 52: 123 unique indices instead of 200
# Repeating indices found in iteration 53: 113 unique indices instead of 200
# Repeating indices found in iteration 54: 122 unique indices instead of 200
# Repeating indices found in iteration 55: 125 unique indices instead of 200
# Repeating indices found in iteration 56: 131 unique indices instead of 200
# Repeating indices found in iteration 57: 126 unique indices instead of 200
# Repeating indices found in iteration 58: 125 unique indices instead of 200
# Repeating indices found in iteration 59: 124 unique indices instead of 200
# Repeating indices found in iteration 60: 126 unique indices instead of 200
# Repeating indices found in iteration 61: 135 unique indices instead of 200
# Repeating indices found in iteration 62: 124 unique indices instead of 200
# Repeating indices found in iteration 63: 132 unique indices instead of 200
# Repeating indices found in iteration 64: 129 unique indices instead of 200
# Repeating indices found in iteration 65: 123 unique indices instead of 200
# Repeating indices found in iteration 66: 125 unique indices instead of 200
# Repeating indices found in iteration 67: 126 unique indices instead of 200
# Repeating indices found in iteration 68: 138 unique indices instead of 200
# Repeating indices found in iteration 69: 126 unique indices instead of 200
# Repeating indices found in iteration 70: 125 unique indices instead of 200
# Repeating indices found in iteration 71: 122 unique indices instead of 200
# Repeating indices found in iteration 72: 120 unique indices instead of 200
# Repeating indices found in iteration 73: 124 unique indices instead of 200
# Repeating indices found in iteration 74: 125 unique indices instead of 200
# Repeating indices found in iteration 75: 126 unique indices instead of 200
# Repeating indices found in iteration 76: 132 unique indices instead of 200
# Repeating indices found in iteration 77: 120 unique indices instead of 200
# Repeating indices found in iteration 78: 128 unique indices instead of 200
# Repeating indices found in iteration 79: 124 unique indices instead of 200
# Repeating indices found in iteration 80: 129 unique indices instead of 200
# Repeating indices found in iteration 81: 121 unique indices instead of 200
# Repeating indices found in iteration 82: 124 unique indices instead of 200
# Repeating indices found in iteration 83: 144 unique indices instead of 200
# Repeating indices found in iteration 84: 124 unique indices instead of 200
# Repeating indices found in iteration 85: 130 unique indices instead of 200
# Repeating indices found in iteration 86: 132 unique indices instead of 200
# Repeating indices found in iteration 87: 127 unique indices instead of 200
# Repeating indices found in iteration 88: 127 unique indices instead of 200
# Repeating indices found in iteration 89: 126 unique indices instead of 200
# Repeating indices found in iteration 90: 124 unique indices instead of 200
# Repeating indices found in iteration 91: 122 unique indices instead of 200
# Repeating indices found in iteration 92: 130 unique indices instead of 200
# Repeating indices found in iteration 93: 127 unique indices instead of 200
# Repeating indices found in iteration 94: 122 unique indices instead of 200
# Repeating indices found in iteration 95: 124 unique indices instead of 200
# Repeating indices found in iteration 96: 128 unique indices instead of 200
# Repeating indices found in iteration 97: 130 unique indices instead of 200
# Repeating indices found in iteration 98: 122 unique indices instead of 200
# Repeating indices found in iteration 99: 120 unique indices instead of 200
# Repeating indices found in iteration 100: 128 unique indices instead of 200
# Repeating indices found in iteration 101: 133 unique indices instead of 200
# Repeating indices found in iteration 102: 128 unique indices instead of 200
# Repeating indices found in iteration 103: 127 unique indices instead of 200
# Repeating indices found in iteration 104: 117 unique indices instead of 200
# Repeating indices found in iteration 105: 117 unique indices instead of 200
# Repeating indices found in iteration 106: 126 unique indices instead of 200
# Repeating indices found in iteration 107: 131 unique indices instead of 200
# Repeating indices found in iteration 108: 121 unique indices instead of 200
# Repeating indices found in iteration 109: 134 unique indices instead of 200
# Repeating indices found in iteration 110: 127 unique indices instead of 200
# Repeating indices found in iteration 111: 132 unique indices instead of 200
# Repeating indices found in iteration 112: 129 unique indices instead of 200
# Repeating indices found in iteration 113: 132 unique indices instead of 200
# Repeating indices found in iteration 114: 125 unique indices instead of 200
# Repeating indices found in iteration 115: 125 unique indices instead of 200
# Repeating indices found in iteration 116: 130 unique indices instead of 200
# Repeating indices found in iteration 117: 130 unique indices instead of 200
# Repeating indices found in iteration 118: 127 unique indices instead of 200
# Repeating indices found in iteration 119: 116 unique indices instead of 200
# Repeating indices found in iteration 120: 119 unique indices instead of 200
# Repeating indices found in iteration 121: 124 unique indices instead of 200
# Repeating indices found in iteration 122: 117 unique indices instead of 200
# Repeating indices found in iteration 123: 129 unique indices instead of 200
# Repeating indices found in iteration 124: 122 unique indices instead of 200
# Repeating indices found in iteration 125: 113 unique indices instead of 200
# Repeating indices found in iteration 126: 123 unique indices instead of 200
# Repeating indices found in iteration 127: 129 unique indices instead of 200
# Repeating indices found in iteration 128: 118 unique indices instead of 200
# Repeating indices found in iteration 129: 125 unique indices instead of 200
# Repeating indices found in iteration 130: 128 unique indices instead of 200
# Repeating indices found in iteration 131: 124 unique indices instead of 200
# Repeating indices found in iteration 132: 124 unique indices instead of 200
# ...
# Repeating indices found in iteration 290: 126 unique indices instead of 200
# Repeating indices found in iteration 291: 130 unique indices instead of 200
# Repeating indices found in iteration 292: 127 unique indices instead of 200
# Repeating indices found in iteration 293: 128 unique indices instead of 200
# Repeating indices found in iteration 294: 133 unique indices instead of 200
# Repeating indices found in iteration 295: 124 unique indices instead of 200
# Repeating indices found in iteration 296: 123 unique indices instead of 200
# Repeating indices found in iteration 297: 131 unique indices instead of 200
# Repeating indices found in iteration 298: 133 unique indices instead of 200
# Repeating indices found in iteration 299: 123 unique indices instead of 200
# Repeating indices found in iteration 300: 120 unique indices instead of 200
# Repeating indices found in iteration 301: 120 unique indices instead of 200
# Repeating indices found in iteration 302: 128 unique indices instead of 200
# Repeating indices found in iteration 303: 124 unique indices instead of 200
# Repeating indices found in iteration 304: 130 unique indices instead of 200
# Repeating indices found in iteration 305: 128 unique indices instead of 200
# Repeating indices found in iteration 306: 124 unique indices instead of 200
# Repeating indices found in iteration 307: 123 unique indices instead of 200
# Repeating indices found in iteration 308: 129 unique indices instead of 200
# Repeating indices found in iteration 309: 123 unique indices instead of 200
# Repeating indices found in iteration 310: 130 unique indices instead of 200
# Repeating indices found in iteration 311: 129 unique indices instead of 200
# Repeating indices found in iteration 312: 127 unique indices instead of 200
# Repeating indices found in iteration 313: 132 unique indices instead of 200
# Repeating indices found in iteration 314: 124 unique indices instead of 200
# Repeating indices found in iteration 315: 120 unique indices instead of 200
# Repeating indices found in iteration 316: 129 unique indices instead of 200
# Repeating indices found in iteration 317: 126 unique indices instead of 200
# Repeating indices found in iteration 318: 126 unique indices instead of 200
# Repeating indices found in iteration 319: 137 unique indices instead of 200
# Repeating indices found in iteration 320: 133 unique indices instead of 200
# Repeating indices found in iteration 321: 132 unique indices instead of 200
# Repeating indices found in iteration 322: 126 unique indices instead of 200
# Repeating indices found in iteration 323: 122 unique indices instead of 200
# Repeating indices found in iteration 324: 118 unique indices instead of 200
# Repeating indices found in iteration 325: 128 unique indices instead of 200
# Repeating indices found in iteration 326: 136 unique indices instead of 200
# Repeating indices found in iteration 327: 132 unique indices instead of 200
# Repeating indices found in iteration 328: 131 unique indices instead of 200
# Repeating indices found in iteration 329: 124 unique indices instead of 200
# Repeating indices found in iteration 330: 122 unique indices instead of 200
# Repeating indices found in iteration 331: 131 unique indices instead of 200
# Repeating indices found in iteration 332: 130 unique indices instead of 200
# Repeating indices found in iteration 333: 122 unique indices instead of 200
# Repeating indices found in iteration 334: 125 unique indices instead of 200
# Repeating indices found in iteration 335: 135 unique indices instead of 200
# Repeating indices found in iteration 336: 128 unique indices instead of 200
# Repeating indices found in iteration 337: 130 unique indices instead of 200
# Repeating indices found in iteration 338: 136 unique indices instead of 200
# Repeating indices found in iteration 339: 136 unique indices instead of 200
# Repeating indices found in iteration 340: 131 unique indices instead of 200
# Repeating indices found in iteration 341: 129 unique indices instead of 200
# Repeating indices found in iteration 342: 134 unique indices instead of 200
# Repeating indices found in iteration 343: 121 unique indices instead of 200
# Repeating indices found in iteration 344: 129 unique indices instead of 200
# Repeating indices found in iteration 345: 135 unique indices instead of 200
# Repeating indices found in iteration 346: 123 unique indices instead of 200
# Repeating indices found in iteration 347: 125 unique indices instead of 200
# Repeating indices found in iteration 348: 138 unique indices instead of 200
# Repeating indices found in iteration 349: 139 unique indices instead of 200
# Repeating indices found in iteration 350: 129 unique indices instead of 200
# Repeating indices found in iteration 351: 124 unique indices instead of 200
# Repeating indices found in iteration 352: 121 unique indices instead of 200
# Repeating indices found in iteration 353: 122 unique indices instead of 200
# Repeating indices found in iteration 354: 141 unique indices instead of 200
# Repeating indices found in iteration 355: 129 unique indices instead of 200
# Repeating indices found in iteration 356: 126 unique indices instead of 200
# Repeating indices found in iteration 357: 128 unique indices instead of 200
# Repeating indices found in iteration 358: 129 unique indices instead of 200
# Repeating indices found in iteration 359: 133 unique indices instead of 200
# Repeating indices found in iteration 360: 116 unique indices instead of 200
# Repeating indices found in iteration 361: 124 unique indices instead of 200
# Repeating indices found in iteration 362: 128 unique indices instead of 200
# Repeating indices found in iteration 363: 113 unique indices instead of 200
# Repeating indices found in iteration 364: 131 unique indices instead of 200
# Repeating indices found in iteration 365: 132 unique indices instead of 200
# Repeating indices found in iteration 366: 134 unique indices instead of 200
# Repeating indices found in iteration 367: 121 unique indices instead of 200
# Repeating indices found in iteration 368: 125 unique indices instead of 200
# Repeating indices found in iteration 369: 128 unique indices instead of 200
# Repeating indices found in iteration 370: 126 unique indices instead of 200
# Repeating indices found in iteration 371: 130 unique indices instead of 200
# Repeating indices found in iteration 372: 123 unique indices instead of 200
# Repeating indices found in iteration 373: 129 unique indices instead of 200
# Repeating indices found in iteration 374: 129 unique indices instead of 200
# Repeating indices found in iteration 375: 118 unique indices instead of 200
# Repeating indices found in iteration 376: 113 unique indices instead of 200
# Repeating indices found in iteration 377: 128 unique indices instead of 200
# Repeating indices found in iteration 378: 123 unique indices instead of 200
# Repeating indices found in iteration 379: 124 unique indices instead of 200
# Repeating indices found in iteration 380: 138 unique indices instead of 200
# Repeating indices found in iteration 381: 137 unique indices instead of 200
# Repeating indices found in iteration 382: 122 unique indices instead of 200
# Repeating indices found in iteration 383: 129 unique indices instead of 200
# Repeating indices found in iteration 384: 130 unique indices instead of 200
# Repeating indices found in iteration 385: 128 unique indices instead of 200
# Repeating indices found in iteration 386: 125 unique indices instead of 200
# Repeating indices found in iteration 387: 125 unique indices instead of 200
# Repeating indices found in iteration 388: 128 unique indices instead of 200
# Repeating indices found in iteration 389: 126 unique indices instead of 200
# Repeating indices found in iteration 390: 138 unique indices instead of 200
# Repeating indices found in iteration 391: 131 unique indices instead of 200
# Repeating indices found in iteration 392: 124 unique indices instead of 200
# Repeating indices found in iteration 393: 123 unique indices instead of 200
# Repeating indices found in iteration 394: 126 unique indices instead of 200
# Repeating indices found in iteration 395: 120 unique indices instead of 200
# Repeating indices found in iteration 396: 116 unique indices instead of 200
# Repeating indices found in iteration 397: 128 unique indices instead of 200
# Repeating indices found in iteration 398: 127 unique indices instead of 200
# Repeating indices found in iteration 399: 127 unique indices instead of 200
# Repeating indices found in iteration 400: 135 unique indices instead of 200
# Repeating indices found in iteration 401: 132 unique indices instead of 200
# Repeating indices found in iteration 402: 129 unique indices instead of 200
# Repeating indices found in iteration 403: 123 unique indices instead of 200
# Repeating indices found in iteration 404: 127 unique indices instead of 200
# Repeating indices found in iteration 405: 132 unique indices instead of 200
# Repeating indices found in iteration 406: 124 unique indices instead of 200
# Repeating indices found in iteration 407: 130 unique indices instead of 200
# Repeating indices found in iteration 408: 128 unique indices instead of 200
# Repeating indices found in iteration 409: 133 unique indices instead of 200
# Repeating indices found in iteration 410: 121 unique indices instead of 200
# Repeating indices found in iteration 411: 123 unique indices instead of 200
# Repeating indices found in iteration 412: 132 unique indices instead of 200
# Repeating indices found in iteration 413: 126 unique indices instead of 200
# Repeating indices found in iteration 414: 124 unique indices instead of 200
# Repeating indices found in iteration 415: 127 unique indices instead of 200
# Repeating indices found in iteration 416: 119 unique indices instead of 200
# Repeating indices found in iteration 417: 125 unique indices instead of 200
# Repeating indices found in iteration 418: 130 unique indices instead of 200
# Repeating indices found in iteration 419: 123 unique indices instead of 200
# Repeating indices found in iteration 420: 116 unique indices instead of 200
# Repeating indices found in iteration 421: 129 unique indices instead of 200
# Repeating indices found in iteration 422: 118 unique indices instead of 200
# Repeating indices found in iteration 423: 127 unique indices instead of 200
# Repeating indices found in iteration 424: 128 unique indices instead of 200
# Repeating indices found in iteration 425: 120 unique indices instead of 200
# Repeating indices found in iteration 426: 132 unique indices instead of 200
# Repeating indices found in iteration 427: 120 unique indices instead of 200
# Repeating indices found in iteration 428: 118 unique indices instead of 200
# Repeating indices found in iteration 429: 132 unique indices instead of 200
# Repeating indices found in iteration 430: 120 unique indices instead of 200
# Repeating indices found in iteration 431: 123 unique indices instead of 200
# Repeating indices found in iteration 432: 127 unique indices instead of 200
# Repeating indices found in iteration 433: 123 unique indices instead of 200
# Repeating indices found in iteration 434: 119 unique indices instead of 200
# Repeating indices found in iteration 435: 125 unique indices instead of 200
# Repeating indices found in iteration 436: 123 unique indices instead of 200
# Repeating indices found in iteration 437: 132 unique indices instead of 200
# Repeating indices found in iteration 438: 125 unique indices instead of 200
# Repeating indices found in iteration 439: 129 unique indices instead of 200
# Repeating indices found in iteration 440: 135 unique indices instead of 200
# Repeating indices found in iteration 441: 133 unique indices instead of 200
# Repeating indices found in iteration 442: 132 unique indices instead of 200
# Repeating indices found in iteration 443: 129 unique indices instead of 200
# Repeating indices found in iteration 444: 125 unique indices instead of 200
# Repeating indices found in iteration 445: 125 unique indices instead of 200
# Repeating indices found in iteration 446: 129 unique indices instead of 200
# Repeating indices found in iteration 447: 126 unique indices instead of 200
# Repeating indices found in iteration 448: 129 unique indices instead of 200
# Repeating indices found in iteration 449: 133 unique indices instead of 200
# Repeating indices found in iteration 450: 119 unique indices instead of 200
# Repeating indices found in iteration 451: 126 unique indices instead of 200
# Repeating indices found in iteration 452: 128 unique indices instead of 200
# Repeating indices found in iteration 453: 120 unique indices instead of 200
# Repeating indices found in iteration 454: 123 unique indices instead of 200
# Repeating indices found in iteration 455: 129 unique indices instead of 200
# Repeating indices found in iteration 456: 123 unique indices instead of 200
# Repeating indices found in iteration 457: 127 unique indices instead of 200
# Repeating indices found in iteration 458: 128 unique indices instead of 200
# Repeating indices found in iteration 459: 137 unique indices instead of 200
# Repeating indices found in iteration 460: 125 unique indices instead of 200
# Repeating indices found in iteration 461: 132 unique indices instead of 200
# Repeating indices found in iteration 462: 133 unique indices instead of 200
# Repeating indices found in iteration 463: 137 unique indices instead of 200
# Repeating indices found in iteration 464: 119 unique indices instead of 200
# Repeating indices found in iteration 465: 118 unique indices instead of 200
# Repeating indices found in iteration 466: 127 unique indices instead of 200
# Repeating indices found in iteration 467: 124 unique indices instead of 200
# Repeating indices found in iteration 468: 129 unique indices instead of 200
# Repeating indices found in iteration 469: 131 unique indices instead of 200
# Repeating indices found in iteration 470: 120 unique indices instead of 200
# Repeating indices found in iteration 471: 125 unique indices instead of 200
# Repeating indices found in iteration 472: 126 unique indices instead of 200
# Repeating indices found in iteration 473: 122 unique indices instead of 200
# Repeating indices found in iteration 474: 129 unique indices instead of 200
# Repeating indices found in iteration 475: 126 unique indices instead of 200
# Repeating indices found in iteration 476: 126 unique indices instead of 200
# Repeating indices found in iteration 477: 129 unique indices instead of 200
# Repeating indices found in iteration 478: 143 unique indices instead of 200
# Repeating indices found in iteration 479: 120 unique indices instead of 200
# Repeating indices found in iteration 480: 130 unique indices instead of 200
# Repeating indices found in iteration 481: 125 unique indices instead of 200
# Repeating indices found in iteration 482: 130 unique indices instead of 200
# Repeating indices found in iteration 483: 127 unique indices instead of 200
# Repeating indices found in iteration 484: 131 unique indices instead of 200
# Repeating indices found in iteration 485: 123 unique indices instead of 200
# Repeating indices found in iteration 486: 128 unique indices instead of 200
# Repeating indices found in iteration 487: 128 unique indices instead of 200
# Repeating indices found in iteration 488: 117 unique indices instead of 200
# Repeating indices found in iteration 489: 123 unique indices instead of 200
# Repeating indices found in iteration 490: 122 unique indices instead of 200
# Repeating indices found in iteration 491: 130 unique indices instead of 200
# Repeating indices found in iteration 492: 135 unique indices instead of 200
# Repeating indices found in iteration 493: 124 unique indices instead of 200
# Repeating indices found in iteration 494: 128 unique indices instead of 200
# Repeating indices found in iteration 495: 122 unique indices instead of 200
# Repeating indices found in iteration 496: 128 unique indices instead of 200
# Repeating indices found in iteration 497: 123 unique indices instead of 200
# Repeating indices found in iteration 498: 132 unique indices instead of 200
# Repeating indices found in iteration 499: 129 unique indices instead of 200

# %% [markdown]
# ### Idea 2: Calculate the average number of unique top wells over multiple iterations:
# Modify the bootstrap_resample_test function to return the average number of unique top wells and print it after running the test:

# %%
def bootstrap_resample_test(target, predictions, count, n_iterations=100):
    unique_top_wells_counts = []

    for i in range(n_iterations):
        resampled_indices = np.random.choice(target.index, size=len(target), replace=True)
        resampled_target = target.loc[resampled_indices]
        resampled_predictions = predictions.loc[resampled_indices]

        top_wells = resampled_predictions.sort_values(ascending=False).head(count).index
        unique_top_wells = top_wells.nunique()

        unique_top_wells_counts.append(unique_top_wells)

    average_unique_top_wells = np.mean(unique_top_wells_counts)
    return average_unique_top_wells

for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    avg_unique_top_wells = bootstrap_resample_test(random_target, random_predictions, WELLS_FOR_DEVELOPMENT, n_iterations=500)
    print(f"Average number of unique top wells: {avg_unique_top_wells}")
    print()
# Out:
# Checking Region 0:
# Average number of unique top wells: 126.39
#
# Checking Region 1:
# Average number of unique top wells: 126.55
#
# Checking Region 2:
# Average number of unique top wells: 126.952

# %% [markdown]
# ### Idea 3: Calculate the percentage of unique top wells from the total number of wells:
# Calculate the percentage of unique top wells in each iteration and then find the average percentage over multiple iterations. Modify the bootstrap_resample_test function as follows:

# %%
def bootstrap_resample_test(target, predictions, count, n_iterations=100):
    unique_top_wells_percentages = []

    for i in range(n_iterations):
        resampled_indices = np.random.choice(target.index, size=len(target), replace=True)
        resampled_target = target.loc[resampled_indices]
        resampled_predictions = predictions.loc[resampled_indices]

        top_wells = resampled_predictions.sort_values(ascending=False).head(count).index
        unique_top_wells = top_wells.nunique()

        unique_top_wells_percentage = unique_top_wells / count * 100
        unique_top_wells_percentages.append(unique_top_wells_percentage)

    average_unique_top_wells_percentage = np.mean(unique_top_wells_percentages)
    return average_unique_top_wells_percentage

for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    avg_unique_top_wells_percentage = bootstrap_resample_test(random_target, random_predictions, WELLS_FOR_DEVELOPMENT, n_iterations=500)
    print(f"Average percentage of unique top wells: {avg_unique_top_wells_percentage}%")
    print()
# Out:
# Checking Region 0:
# Average percentage of unique top wells: 63.305%
#
# Checking Region 1:
# Average percentage of unique top wells: 63.155%
#
# Checking Region 2:
# Average percentage of unique top wells: 63.46%

# %% [markdown]
# ### Idea 4: Increase the number of wells for profit calculation:
# Increase the number of wells for profit calculation to see if we get a higher count of unique top wells. For example, set the number of wells to 300:

# %%
WELLS_FOR_DEVELOPMENT_300 = 300

for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    bootstrap_resample_test(random_target, random_predictions, WELLS_FOR_DEVELOPMENT_300)
    print()
# Out:
# Checking Region 0:
#
# Checking Region 1:
#
# Checking Region 2:

# %% [markdown]
# The function `bootstrap_resample_test_v2` is designed to perform a bootstrap resampling test on the given target and predictions data. The function accepts four parameters:
# - target: The true target values (volume of reserves) for the oil wells.
# - predictions: The predicted values for the oil wells.
# - count: The number of top wells to consider for the profit calculation.
# - n_iterations: The number of iterations to perform the bootstrap resampling test (default is 100).
#
# Inside the function, we initiate an empty list called `unique_top_wells_list`. Then, for each iteration, we perform the following steps:
#
# 1. Resample the target and predictions data with replacement, creating `resampled_target` and `resampled_predictions`.
# 2. Sort the resampled predictions in descending order, pick the top wells according to the `count` parameter, and calculate the number of unique top wells (`unique_top_wells`).
# 3. Append the unique top wells count to the `unique_top_wells_list`.
#
# After completing all iterations, we calculate the average number of unique top wells (`avg_unique_top_wells`) and the average percentage of unique top wells (`avg_pct_unique_top_wells`) using the values stored in `unique_top_wells_list`. The function then prints out these values.
#
# Finally, we run the `bootstrap_resample_test_v2` function for each region, using the random subsets of the validation data and a `WELLS_FOR_DEVELOPMENT_300` constant set to 300. The output shows the average number of unique top wells and the average percentage of unique top wells for each region.

# %%
def bootstrap_resample_test_v2(target, predictions, count, n_iterations=100):
    n_samples = len(target)
    unique_top_wells_list = []
    
    for i in range(n_iterations):
        resampled_indices = np.random.choice(target.index, size=n_samples, replace=True)
        resampled_target = target.loc[resampled_indices]
        resampled_predictions = predictions.loc[resampled_indices]
        
        top_wells = resampled_predictions.sort_values(ascending=False).head(count).index
        unique_top_wells = top_wells.nunique()
        unique_top_wells_list.append(unique_top_wells)

    avg_unique_top_wells = np.mean(unique_top_wells_list)
    avg_pct_unique_top_wells = (avg_unique_top_wells / count) * 100
    
    print(f"Average number of unique top wells: {avg_unique_top_wells:.3f}")
    print(f"Average percentage of unique top wells: {avg_pct_unique_top_wells:.3f}%")

# %%
for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    print(f"Checking Region {i}:")
    bootstrap_resample_test_v2(random_target, random_predictions, WELLS_FOR_DEVELOPMENT_300)
    print()
# Out:
# Checking Region 0:
# Average number of unique top wells: 189.800
# Average percentage of unique top wells: 63.267%
#
# Checking Region 1:
# Average number of unique top wells: 190.350
# Average percentage of unique top wells: 63.450%
#
# Checking Region 2:
# Average number of unique top wells: 189.990
# Average percentage of unique top wells: 63.330%

# %% [markdown]
# # 4.1 Summary - I have no Idea
#  We began by loading the geological exploration data for three regions, which included the features and the volume of reserves in the oil wells.
#
# We split the data into training and validation sets and trained a linear regression model for each region.
#
# We used the trained models to make predictions on the validation sets, and then we calculated the profits for each region using a function called calculate_profit. The initial results for each region were:
#
# - Region 0: Profit: 33208260.43139851 USD
# - Region 1: Profit: 24150866.966815114 USD
# - Region 2: Profit: 27103499.635998324 USD
# <br>
# <br>
# We identified an issue with the bootstrap_resample_test function, where the unique top wells count did not equal the expected count of 200. We realized that the number of points considered was not 500, as mentioned in the project description.
#
# We then generated random subsets of 500 points for each region and ran the bootstrap_resample_test function again. The output showed that the average number of unique top wells was around 126-127, and the average percentage of unique top wells was around 63% for all regions.
#
# As an additional step, we increased the count to 300 and ran the bootstrap_resample_test function. The results showed a similar average percentage of unique top wells (around 63%) for all regions.
#
# ### In conclusion <br>
# after addressing the issue of the number of points considered and adjusting the count of wells for development, we found that the average percentage of unique top wells across all regions remained around 63%. This information can be used to make informed decisions about where to develop new oil wells.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>Reviewer's comment</b>
#
# Function for profit calculation is almost correct, but there is a subtle problem: after sampling with replacement in the bootstrap loop we can end up with repeating indices in targets/predictions, and `target.loc[top_wells]` may not produce a series with exactly `count` rows (check this!). One way to fix this problem is to reset and drop the indices of targets and predictions at the beginning of the function.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's Comment</b> <br>
#
#
# Summary of Findings:
#
# 1. We began by loading the geological exploration data for three regions, which included the features and the volume of reserves in the oil wells.
# 2. We split the data into training and validation sets and trained a linear regression model for each region.
# 3. We used the trained models to make predictions on the validation sets, and then we calculated the profits for each region using a function called `calculate_profit`. The initial results for each region were:
#    - Region 0: Profit: 33208260.43139851 USD
#    - Region 1: Profit: 24150866.966815114 USD
#    - Region 2: Profit: 27103499.635998324 USD
# 4. We identified an issue with the `bootstrap_resample_test` function, where the unique top wells count did not equal the expected count of 200. We realized that the number of points considered was not 500, as mentioned in the project description.
# 5. We then generated random subsets of 500 points for each region and ran the `bootstrap_resample_test` function again. The output showed that the average number of unique top wells was around 126-127, and the average percentage of unique top wells was around 63% for all regions.
# 6. As an additional step, we increased the count to 300 and ran the `bootstrap_resample_test` function. The results showed a similar average percentage of unique top wells (around 63%) for all regions.
#
# In conclusion, after addressing the issue of the number of points considered and adjusting the count of wells for development, we found that the average percentage of unique top wells across all regions remained around 63%. This information can be used to make informed decisions about where to develop new oil wells.
#
# __** But Also... !@#$% **__
#
# </div>

# %% [markdown]
# ## 4.2. Summarize the target volume of reserves in accordance with these

# %%
import matplotlib.pyplot as plt

# Set up the figure and axis
fig, ax = plt.subplots()

# Define the x and y values
regions = list(region_profits.keys())
profits = list(region_profits.values())

# Create a bar chart
ax.bar(regions, profits, color=['blue', 'orange', 'green'])

# Customize the chart
ax.set_xticks(regions)
ax.set_xticklabels([f"Region {i}" for i in regions])
ax.set_ylabel('Profit (USD)')
ax.set_title('Profits for Each Region')

# Display the chart
plt.show()

# %% [markdown]
# This code will calculate the profit for each region using the calculate_profit function and print the results. It will then determine and print the region with the highest profit.

# %% [markdown]
# # Summary of our findings for Section 4 so far:
# - **Region 0:**
#     - Profit: **33,208,260.43 USD**
# - **Region 1:**
#     - Profit: **24,150,866.97 USD**
# - **Region 2:**
#     - Profit: **27,103,499.64 USD**
#
# Based on the calculated profits for each region, **Region 0** has the highest profit of **33,208,260.43 USD**. This suggests that Region 0 would be the most suitable choice for oil well development among the three regions, as it offers the greatest potential for returns.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment</b>
#
# Right, but this is more like maximimum possible profit on historical data, assuming we could select just overall top 200 wells. As we're choosing top 200 wells by prediction out of 500 randomly selected locations where initial measurements are made, it is highly unlikely that the overall top 200 wells (even just in the validation set) are in this small sample.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>student's comment</b>
#
# We addressed this concern by generating random subsets of 500 points for each region and performing the calculations on these subsets. We then used the bootstrap_resample_test function to investigate the percentage of unique top wells in these random subsets. The results indicated that the average percentage of unique top wells was around 63% across all regions, which provides a more realistic estimation of the profit based on the random sampling of 500 wells.
#
# By making these adjustments, we have taken into consideration the fact that the actual top wells might not be present in the random subset of 500 wells, and we have provided a more accurate assessment of the profits and risks associated with selecting a region for new oil well development.
#
# ## This is where things finally start to make sense
# ### run bootstrap_resample_test_v3
# Although it occurs to me now that I may never have actually run the code to calculate the profit for each region once we updated the bootstrap_resample_test function. I'll do that now.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment V2</b>
#
# It seems that you overthinked my comments a bit. :) Let me try to clarify some points.
#
# 1. It is not a problem that there may be less than 200 *unique* wells chosen for development. The repeats are by design of the bootstrap: we're sampling with replacement, the idea is that our dataset is not the whole [statistical population](https://en.wikipedia.org/wiki/Statistical_population), i.e. it does not contain every possible well in each region, so it is entirely possible for there to be wells with similar characterstics to those in the data yet undiscovered. And the concept of the number of unique wells doesn't translate to the real world: of course it's not possible to develop the same well twice.
#     So while you did some interesting research on how to increase the number of unique wells in the set of wells chosen for development, it is not quite what I was getting at, unfortunately.
# 2. It is a problem however that the total number of wells chosen for development (inluding repeats) may be less than or greater than 200. Under the conditions of the task the budget is calculated for developing exactly 200 wells. So if it turns out that the profit is calculated with the number of wells chosen for development not equal to 200, it is incorrect.
#
#     The good news is that the only thing needed to fix this problem is to reset and drop the indices at the beginning of the profit calculation function, which you already did! :)
#
# 3. Now to get a distribution of profits for each region you just need to do the following:
#
#     1. Repeat the following steps for 1000 iterations.
#     2. Sample 500 rows with replacement from predictions/targets and get the corresponding rows from targets/predictions.
#     3. Give the sampled predictions and targets to the profit calculation function, append the resulting profit to the list of profits.
#
#     That's it!
#
# 4. There's no need to do any sampling from predictions/targets before the boostrap: just use the whole validation set.
#
# 5. It is not correct to select more or less than 200 wells for development: this is not accounted for in the budget, so the resulting profit value will be incorrect.
#
# 6. Here I'll try to justify why the above makes sense. Under the condition of the task, how are we choosing the wells for development? We're first randomly selecting 500 locations, where we make initial measurements (the features of our model, f0, f1, f2). Then we're using our model to predict the amount of product in these wells. Then we select the top 200 wells by prediction for development. How can we best estimate the profit distribution in each region? Well, for example, we could just repeat this experiment 1000 times. But of course it is very expensive, so we're trying to simulate the experiment with the bootstrap.
#
# </div>

# %%
def bootstrap_resample_test_v3(target, predictions, count, n_iterations=100):
    n_samples = len(target)
    profits_list = []
    
    for i in range(n_iterations):
        resampled_indices = np.random.choice(target.index, size=n_samples, replace=True)
        resampled_target = target.loc[resampled_indices]
        resampled_predictions = predictions.loc[resampled_indices]
        
        top_wells = resampled_predictions.sort_values(ascending=False).head(count).index
        profit = calculate_profit(resampled_target, resampled_predictions, count)
        profits_list.append(profit)

    avg_profit = np.mean(profits_list)
    return avg_profit

# %% [markdown]
# ## 4.2 Summary - Updated Profit Calculations

# %%
updated_profits = []
for i, (random_target, random_predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    profit = bootstrap_resample_test_v3(random_target, random_predictions, WELLS_FOR_DEVELOPMENT)
    updated_profits.append(profit)

# # Print the output
# for i, profit in enumerate(updated_profits):
#     print(f"Region {i}: Updated Profit: {profit:.2f} USD")

# Generate the report
report_template = """
## 4.2 Summary - Updated Profit Calculations

After making the necessary updates to the profit calculation process and considering random subsets of 500 points for each region, we recalculated the profits for each region. The updated profit calculations are as follows:

- Region 0: Updated Profit: {:.2f} USD
- Region 1: Updated Profit: {:.2f} USD
- Region 2: Updated Profit: {:.2f} USD

These updated profit values provide a more realistic estimation of potential profits in each region, taking into account the random sampling of points and the improved profit calculation process. This information can be used to make more informed decisions about which region to develop new oil wells.
"""

print(report_template.format(updated_profits[0], updated_profits[1], updated_profits[2]))
# Out:
# ## 4.2 Summary - Updated Profit Calculations
#
# After making the necessary updates to the profit calculation process and considering random subsets of 500 points for each region, we recalculated the profits for each region. The updated profit calculations are as follows:
#
# - Region 0: Updated Profit: 110518475.01 USD
# - Region 1: Updated Profit: 111382736.85 USD
# - Region 2: Updated Profit: 104996624.33 USD
#
# These updated profit values provide a more realistic estimation of potential profits in each region, taking into account the random sampling of points and the improved profit calculation process. This information can be used to make more informed decisions about which region to develop new oil wells.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment V2</b>
#
# Everything from `calculate_profit` function up to this point is not needed: the subpoints of task 4 just explain what the profit calculation function should do, but to estimate actual distribution of profit we're doing the boostrap
#
# </div>

# %% [markdown]
# # 5. Calculate risks and profit for each region
# ### 5.1. Use the bootstrapping technique with 1000 samples to find the distribution of profit:

# %%
def bootstrap(target, predictions, count, wells_for_development, n_samples=1000, random_state=42):
    np.random.seed(random_state)

    profits = []
    for _ in range(n_samples):
        target_sample = target.sample(count, replace=True)
        predictions_sample = predictions.loc[target_sample.index]

        # Select the best wells by prediction
        best_wells = predictions_sample.sort_values(ascending=False).head(wells_for_development).index
        target_best_wells = target_sample.loc[best_wells]

        profit = calculate_profit(target_best_wells, predictions_sample.loc[best_wells], wells_for_development)
        profits.append(profit)
        
    return pd.Series(profits)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment V2</b>
#
# The following lines are unnecessary, as selecting the wells is already done inside the `calculate_profit` function
# ```python
# # Select the best wells by prediction
# best_wells = predictions_sample.sort_values(ascending=False).head(wells_for_development).index
# target_best_wells = target_sample.loc[best_wells]
# ```
#
# </div>

# %% [markdown]
# Now that we have the modified bootstrap function, we can use it to calculate the distribution of profits for each region by applying it to the target and predictions data. Once we have the profit distribution for each region, we can calculate the confidence intervals and risks associated with each region.

# %% [markdown]
# ### 5.2. Find average profit, 95% confidence interval, and risk of losses:

# %%
def calculate_statistics(profit_samples):
    mean_profit = profit_samples.mean()
    lower = profit_samples.quantile(0.025)
    upper = profit_samples.quantile(0.975)
    risk_of_losses = (profit_samples < 0).mean() * 100
    
    return mean_profit, lower, upper, risk_of_losses

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment V2</b>
#
# Why not use this function instead of copying the code below? :)
#
# </div>

# %%
### This code block uses the updated, randomly sampled dataset.

# Calculate the distribution of profits for each region
profits_distributions = []
for i, (target_valid, predictions) in enumerate(zip(random_targets_valid, random_predictions_list)):
    profit_distribution = bootstrap(target_valid, predictions, 500, WELLS_FOR_DEVELOPMENT)
    profits_distributions.append(profit_distribution)

# Calculate confidence intervals and risks for each region
for i, profit_distribution in enumerate(profits_distributions):
    lower_bound = profit_distribution.quantile(0.025)
    upper_bound = profit_distribution.quantile(0.975)
    mean_profit = profit_distribution.mean()
    risk = (profit_distribution < 0).mean() * 100

    print(f"Region {i}:")
    print(f"  Mean profit: {mean_profit:.2f} USD")
    print(f"  95% confidence interval: ({lower_bound:.2f}, {upper_bound:.2f}) USD")
    print(f"  Risk: {risk:.2f}%\n")
# Out:
# Region 0:
#   Mean profit: 734014948.67 USD
#   95% confidence interval: (407331675.79, 1356152916.44) USD
#   Risk: 0.00%
#
# Region 1:
#   Mean profit: 765111698.69 USD
#   95% confidence interval: (456240014.79, 1406198862.29) USD
#   Risk: 0.00%
#
# Region 2:
#   Mean profit: 688803958.86 USD
#   95% confidence interval: (389222385.23, 1228731095.64) USD
#   Risk: 0.00%

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment V2</b>
#
# As mentioned above, here we need to use `targets_valid` and `predictions_list` instead of the random samples from them.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>Reviewer's comment</b>
#
# 1. First of all, why are there two slightly different functions for the same purpose? :)
# 2. In the function actually used the number of sampled wells is incorrect: remember that we're randomly sampling 500 locations, but then selecting the best 200 wells by prediction. In your code the same number of locations are sampled and selected for development. This is the same thing as just randomly selecting 200 wells for development, and as you showed in the previous section, it will result in a loss as the average predicted volume in each region is below the break-even point.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment</b>
#
# agreed, updated as sugested
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Needed statistics are calculated correctly
#
# </div>

# %%
# Calculate confidence intervals and risks for each region and store the statistics
statistics = []
for i, profit_distribution in enumerate(profits_distributions):
    stats = calculate_statistics(profit_distribution)
    statistics.append(stats)

    lower_bound = stats[1]
    upper_bound = stats[2]
    mean_profit = stats[0]
    risk = stats[3]

# %%
import numpy as np
import matplotlib.pyplot as plt

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Set up the data
regions = [0, 1, 2]
mean_profits = [stats[0] for stats in statistics]
risks = [stats[3] for stats in statistics]

# Set up the plot
x = np.arange(len(regions))  # the label locations
width = 0.35  # the width of the bars

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Mean profit bar chart
rects1 = ax1.bar(x, mean_profits, width, label='Mean Profit')
ax1.set_ylabel('Mean Profit (USD)')
ax1.set_title('Mean Profit by Region')
ax1.set_xticks(x)
ax1.set_xticklabels(regions)
autolabel(rects1, ax1)

# Risk of losses bar chart
rects2 = ax2.bar(x, risks, width, label='Risk of Losses', color='orange')
ax2.set_ylabel('Risk of Losses (%)')
ax2.set_title('Risk of Losses by Region')
ax2.set_xticks(x)
ax2.set_xticklabels(regions)
autolabel(rects2, ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3. Provide findings: suggest a region for development of oil wells and justify the choice:

# %% [markdown]
# Here are the summarized findings for each region: <br>
# <br>
# Region 0: <br>
# Mean profit: 13,241,706.64 USD <br>
# 95% confidence interval: (1,703,908.64, 24,825,714.43) USD <br>
# Risk of losses: 1.30% <br>
# <br>
# Region 1: <br>
# Mean profit: 20,005,596.41 USD <br>
# 95% confidence interval: (14,393,563.59, 23,178,061.58) USD <br>
# Risk of losses: 0.00% <br>
# <br>
# Region 2: <br>
# Mean profit: 9,018,073.08 USD <br>
# 95% confidence interval: (-3,195,680.82, 20,766,120.46) USD <br>
# Risk of losses: 6.60% <br>
# <br>
# Based on the findings, I would suggest developing oil wells in Region 1. This region has the highest mean profit and the lowest risk of losses. The 95% confidence interval for Region 1 is also entirely positive, indicating a high probability of making a profit.

# %% [markdown]
# ### Auto Generated Report
# Same as above, only the output is generated by code, rather then hard coded in markdown.

# %%
# Print the summarized findings for each region
for i, stats in enumerate(statistics):
    mean_profit = stats[0]
    lower_ci = stats[1]
    upper_ci = stats[2]
    risk_of_losses = stats[3]

    print(f"Region {i}:")
    print(f"  Mean profit: {mean_profit:,.2f} USD")
    print(f"  95% confidence interval: ({lower_ci:,.2f}, {upper_ci:,.2f}) USD")
    print(f"  Risk of losses: {risk_of_losses:.2f}%")
    print()

# Find the best region based on the highest mean profit and the lowest risk of losses
best_region = max(enumerate(statistics), key=lambda x: (x[1][0], -x[1][3]))[0]

print(f"""
Based on the findings, I would suggest developing oil wells in Region {best_region}. 
This region has the highest mean profit and the lowest risk of losses. 
The 95% confidence interval for Region {best_region} is also entirely positive, 
indicating a high probability of making a profit.
""")
# Out:
# Region 0:
#   Mean profit: 734,014,948.67 USD
#   95% confidence interval: (407,331,675.79, 1,356,152,916.44) USD
#   Risk of losses: 0.00%
#
# Region 1:
#   Mean profit: 765,111,698.69 USD
#   95% confidence interval: (456,240,014.79, 1,406,198,862.29) USD
#   Risk of losses: 0.00%
#
# Region 2:
#   Mean profit: 688,803,958.86 USD
#   95% confidence interval: (389,222,385.23, 1,228,731,095.64) USD
#   Risk of losses: 0.00%
#
#
# Based on the findings, I would suggest developing oil wells in Region 1.
# This region has the highest mean profit and the lowest risk of losses.
# The 95% confidence interval for Region 1 is also entirely positive,
# indicating a high probability of making a profit.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment</b>
#
# Yep, the results should make more sense after fixing the problems above
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment</b> <br>
# <br>
# improved our results. Thanks for your help.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment V2</b>
#
# Please check the results once again
#
# </div>

# %% [markdown]
# # Project evaluation
# We’ve put together the evaluation criteria for the project. Read this carefully before moving on to the task.
# Here’s what the reviewers will look at when reviewing your project:
# * How did you prepare the data for training?
# * Have you followed all the steps of the instructions?
# * Have you taken into account all the business conditions?
# * What are your findings about the task study?
# * Have you applied the Bootstrapping technique correctly?
# * Have you suggested the best region for well development? Is the choice justified?
# * Did you avoid code duplication?
# * Have you kept to the project structure and kept the code neat?
# The Knowledge Base has everything you need to complete the project.
# Good luck!
